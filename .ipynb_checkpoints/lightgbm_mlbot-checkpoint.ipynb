# %%
# 必要なライブラリのインポート
import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
import ccxt
from datetime import datetime, timedelta
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from sklearn.model_selection import GridSearchCV, train_test_split, KFold, RandomizedSearchCV
import warnings
import os
import sweetviz as sv
from IPython.display import IFrame
import time
import requests
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import cross_val_score
import joblib
import optuna
from lightgbm import early_stopping
warnings.filterwarnings('ignore')

# %% [markdown]
# # データ取得

# %%
# データの読み込みと文字列として保存されている日時情報を日時型のデータに変換
df = pd.read_csv('btc_usdt_1h_2018_to_now.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
# タイムスタンプでソートとインデックスのリセット
df.sort_values('timestamp', inplace=True)#inplaceで新しいdataframeを作成せず元のを変更
# 列をインデックス（行ラベル）として設定
df.set_index('timestamp', inplace=True)

# %%
# 欠損値処理
df.fillna(method='ffill', inplace=True)
df.dropna(inplace=True)

# %%
# 特徴量エンジニアリング
# 移動平均線の計算
df['SMA_10'] = df['close'].rolling(window=10).mean()
df['SMA_20'] = df['close'].rolling(window=20).mean()
df['SMA_30'] = df['close'].rolling(window=30).mean()
df['SMA_100'] = df['close'].rolling(window=100).mean()
df['SMA_200'] = df['close'].rolling(window=200).mean()

# 指数移動平均線の計算
df['EMA_20'] = df['close'].ewm(span=20, adjust=False).mean()
df['EMA_200'] = df['close'].ewm(span=200, adjust=False).mean()

# RSIの計算
def compute_RSI(data, time_window):
    diff = data.diff(1) #1つ前の行との違い
    up_chg = diff.clip(lower=0) #差分が負の物は0に変換
    down_chg = -diff.clip(upper=0) #差分が0より大きいものを全て0に置き換える
    up_chg_avg = up_chg.ewm(com=time_window - 1, min_periods=time_window).mean() #価格が上昇した指数移動平均
    down_chg_avg = down_chg.ewm(com=time_window - 1, min_periods=time_window).mean()
    rs = up_chg_avg / down_chg_avg #上昇した強さと下落した強さの比率
    rsi = 100 - 100 / (1 + rs) 
    return rsi

df['RSI_14'] = compute_RSI(df['close'], 14)

# MACDの計算
df['EMA_12'] = df['close'].ewm(span=12, adjust=False).mean()
df['EMA_26'] = df['close'].ewm(span=26, adjust=False).mean()
df['MACD'] = df['EMA_12'] - df['EMA_26']
df['Signal_Line'] = df['MACD'].ewm(span=9, adjust=False).mean()

# ボリンジャーバンドの計算
df['STD_20'] = df['close'].rolling(window=20).std() #stdは標準偏差(データのばらつき度合い)を計算
df['Upper_Band'] = df['SMA_20'] + (df['STD_20'] * 2)
df['Lower_Band'] = df['SMA_20'] - (df['STD_20'] * 2)

# 遅延特徴量の作成
for lag in range(1, 6): #shift(lag) は、df['close'] のデータを lag 分だけ下にシフト
    df[f'lag_{lag}'] = df['close'].shift(lag) #lag_1からlag_5 までの5つの遅延列が作成

# 時間に関する特徴量
df['hour'] = df.index.hour
df['day_of_week'] = df.index.dayofweek #曜日は0から6の値で表される

#ATR（平均真の範囲、Average True Range）
df['TR'] = df['high'] - df['low']
df['ATR_14'] = df['TR'].rolling(window=14).mean()

#ADX（平均方向性指数、Average Directional Index）
def compute_ADX(data, period=14):
    high = data['high']
    low = data['low']
    close = data['close']
    
    plus_dm = high.diff()
    minus_dm = low.diff()

    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0

    tr = high.combine(low, max) - low.combine(close.shift(), min)

    atr = tr.rolling(window=period).mean()

    plus_di = 100 * (plus_dm.ewm(alpha=1/period).mean() / atr)
    minus_di = abs(100 * (minus_dm.ewm(alpha=1/period).mean() / atr))
    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100
    adx = dx.rolling(window=period).mean()
    
    return adx

df['ADX_14'] = compute_ADX(df)

#CCI（商品チャンネル指数、Commodity Channel Index）
df['TP'] = (df['high'] + df['low'] + df['close']) / 3
df['CCI_14'] = (df['TP'] - df['TP'].rolling(window=14).mean()) / (0.015 * df['TP'].rolling(window=14).std())

#OBV（オンバランスボリューム、On-Balance Volume）
df['OBV'] = (np.sign(df['close'].diff()) * df['volume']).fillna(0).cumsum()

#Stochastic Oscillator（ストキャスティクス）
df['L14'] = df['low'].rolling(window=14).min()
df['H14'] = df['high'].rolling(window=14).max()
df['%K'] = 100 * (df['close'] - df['L14']) / (df['H14'] - df['L14'])
df['%D'] = df['%K'].rolling(window=3).mean()

df['Volatility'] = df['close'].rolling(window=10).std()
df['Volume_Change'] = df['volume'].pct_change()

# %%
# 目標変数の作成
df['return'] = df['close'].pct_change().shift(-1) #前の行とのパーセンテージの変化
df['target'] = (df['return'] > 0).astype(int) #価格が上昇したらTrue

# %%
# 欠損値の削除
df.dropna(subset=['target'], inplace=True)

# %%
# 特徴量と目標変数の定義
features = ['open', 'high', 'low', 'close', 'volume', 'SMA_10', 'SMA_30','SMA_100', 'SMA_200',
            'EMA_20',  'EMA_200', 'RSI_14', 'MACD', 'Signal_Line',
            'Upper_Band', 'Lower_Band', 'ATR_14', 'ADX_14', 'CCI_14', 'OBV', '%K', '%D', 'hour', 'day_of_week'] + [f'lag_{lag}' for lag in range(1,6)]

X = df[features]
y = df['target'] #価格が上昇すれば1下落すれば0

# %%
# データの分割（時間ベースでの分割）
split_date = '2024-01-01'
X_train = X[X.index < split_date]
X_test = X[X.index >= split_date]
y_train = y[y.index < split_date]
y_test = y[y.index >= split_date]

# %%
# LightGBM用のデータセットを作成
lgb_train = lgb.Dataset(X_train, y_train)  # 訓練データをLightGBMのデータセット形式に変換
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)  # 評価データも同様に変換し、訓練データを基準に指定

# パラメータの設定
params = {
    'objective': 'binary',  # 目的関数を2値分類問題に設定
    'metric': 'binary_logloss',  # モデル評価の指標としてbinary_loglossを指定
    'num_iterations': 10000,  # 最大のイテレーション数を指定（モデルの学習を行う繰り返し数）
    'verbosity': -1,  # ログ出力の詳細度を制御、-1で詳細な出力を抑制
}

# モデルの訓練
print('Starting training...')
gbm = lgb.train(
    params,  # 指定したパラメータでモデルを訓練
    lgb_train,  # 訓練用データセット
    valid_sets=[lgb_train, lgb_eval],  # 訓練と評価データセットを指定し、途中経過をモニタリング
    num_boost_round=1000,  # 最大1000回のブースティングを実行
    callbacks=[lgb.early_stopping(stopping_rounds=50)]  # 50回連続で改善が見られない場合に訓練を早期終了
)

# 予測の実行
print('Making predictions...')
y_pred_prob = gbm.predict(X_test, num_iteration=gbm.best_iteration)  # テストデータに対する予測確率を計算
y_pred = (y_pred_prob > 0.5).astype(int)  # 確率が0.5を超えたものを1（正例）、それ以下を0（負例）として2値分類
# Out:
# Starting training...
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's binary_logloss: 0.68227	valid_1's binary_logloss: 0.690687
# Making predictions...

# %%
# 予測結果をCSVファイルに保存
np.savetxt("lgb_pred.csv", y_pred, delimiter=",")

# %%
# モデルの評価
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
print('Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5302097726416279
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.52      0.52      0.52      3898
#            1       0.54      0.54      0.54      4063
#
#     accuracy                           0.53      7961
#    macro avg       0.53      0.53      0.53      7961
# weighted avg       0.53      0.53      0.53      7961

# %%
auc = roc_auc_score(y_test, y_pred_prob)
print('ROC AUC Score:', auc)
# Out:
# ROC AUC Score: 0.5398978088437029

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve')
plt.show()

# %%
lgb_model = lgb.LGBMClassifier(objective='binary', metric='binary_logloss', verbosity=-1)
scores = cross_val_score(lgb_model, X_train, y_train, cv=5, scoring='accuracy')
print("Cross-validated accuracy:", scores.mean())
# Out:
# Cross-validated accuracy: 0.5126170758404354

# %%
# 初期設定
initial_capital = 1000000
capital = initial_capital  # 初期資金をリセット
capital_history = []
positions = []
buy_signals = []
sell_signals = []

leverage = 2  # レバレッジ

# 現在のポジションの状態を示す変数
current_position = 0  # 1=ロング, -1=ショート, 0=ポジションなし

# テスト期間の日付リスト
test_dates = X_test.index

for i in range(len(test_dates) - 1):
    date = test_dates[i]
    prediction = y_pred[i]
    close_price = df.loc[date, 'close']
    next_date = test_dates[i + 1]
    next_close_price = df.loc[next_date, 'close']
    
    # ポジションの決定と変更
    if prediction == 1:  # 上がると予想
        if current_position == -1:  # 現在ショートなら決済してロングに変更
            sell_signals.append((date, close_price))  # ショート決済
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        elif current_position == 0:
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        else:
            current_position = 1
        

    elif prediction == 0:  # 下がると予想
        if current_position == 1:  # 現在ロングなら決済してショートに変更
            buy_signals.append((date, close_price))  # ロング決済
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        elif current_position == 0:
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        else:
            current_position = -1

    # リターンの計算
    ret = (next_close_price - close_price) / close_price * current_position * leverage
    capital = capital * (1 + ret)
    capital_history.append(capital)
    positions.append(current_position)

# バックテスト結果のデータフレーム作成
backtest_results = pd.DataFrame(index=test_dates[:-1])
backtest_results['Capital'] = capital_history
backtest_results['Position'] = positions

# リターンの計算
backtest_results['Return'] = backtest_results['Capital'].pct_change().fillna(0)

# シャープレシオの計算（リスクフリーレートは0と仮定）
sharpe_ratio = (backtest_results['Return'].mean() / backtest_results['Return'].std()) * np.sqrt(365 * 24)

print('Final capital:', capital)
print('Sharpe Ratio:', sharpe_ratio)

# 資産推移と売買のプロット
plt.figure(figsize=(12, 12))

# 1つ目のグラフ: 資産推移のプロット
plt.subplot(2, 1, 1)
plt.plot(backtest_results.index, backtest_results['Capital'], label='Capital Over Time')
plt.title('Capital Over Time')
plt.xlabel('Date')
plt.ylabel('Capital')
plt.legend()

# 2つ目のグラフ: BTC価格と売買シグナルのプロット
plt.subplot(2, 1, 2)
plt.plot(df.loc[test_dates[:-1], 'close'], label='BTC Price', color='blue')

# 買いのシグナル（緑の丸）
if buy_signals:
    buy_dates, buy_prices = zip(*buy_signals)
    plt.scatter(buy_dates, buy_prices, color='green', label='Buy Signal', marker='o')

# 売りのシグナル（赤の丸）
if sell_signals:
    sell_dates, sell_prices = zip(*sell_signals)
    plt.scatter(sell_dates, sell_prices, color='red', label='Sell Signal', marker='o')

plt.title('BTC Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('BTC Price')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final capital: 3086832.6201648456
# Sharpe Ratio: 1.7136418142219279

# %%
# リターン計算やポジションサイズの確認
print("Return:", ret)
# Out:
# Return: 0.001506341673328578

# %%
# リターン分布のプロット
plt.figure(figsize=(12,6))
sns.histplot(backtest_results['Return'], bins=50, kde=True)
plt.title('Returns Distribution')
plt.show()

# %%
backtest_results['Return']
# Out:
# timestamp
# 2024-01-01 00:00:00    0.000000
# 2024-01-01 01:00:00    0.001523
# 2024-01-01 02:00:00    0.011771
# 2024-01-01 03:00:00    0.003284
# 2024-01-01 04:00:00   -0.007829
#                          ...
# 2024-11-27 11:00:00    0.002828
# 2024-11-27 12:00:00   -0.016342
# 2024-11-27 13:00:00   -0.012081
# 2024-11-27 14:00:00   -0.015239
# 2024-11-27 15:00:00    0.001506
# Name: Return, Length: 7960, dtype: float64

# %%
# モデルの保存
gbm.save_model('lightgbm_btc_model.txt')

# %% [markdown]
# # ハイパーパラメータチューニング

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
import numpy as np
from lightgbm import early_stopping

# Optunaによるハイパーパラメータ調整
def objective(trial):
    param = {
        'objective': 'binary',
        'metric': 'binary_logloss',
        'boosting_type': 'gbdt',
        'class_weight': 'balanced',
        'n_estimators': trial.suggest_int('n_estimators', 200, 1500),
        'max_depth': trial.suggest_int('max_depth', 4, 20),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
        'num_leaves': trial.suggest_int('num_leaves', 20, 256),
        'max_bin': trial.suggest_int('max_bin', 200, 500),  # max_binの追加
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 100),
        'min_child_weight': trial.suggest_float('min_child_weight', 1e-3, 10.0),
        'min_split_gain': trial.suggest_float('min_split_gain', 0.0, 0.5),  # min_split_gainの追加
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'subsample_freq': trial.suggest_int('subsample_freq', 1, 10),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 1.0),  # feature_fractionの追加
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 1.0),  # bagging_fractionの追加
        'bagging_seed': 42,
        'lambda_l1': trial.suggest_float('lambda_l1', 0.0, 5.0),  # L1正則化
        'lambda_l2': trial.suggest_float('lambda_l2', 0.0, 5.0),  # L2正則化
        'random_state': 42,
        'device_type': 'cpu'  # GPUが使用可能なら 'gpu' に変更
    }

    model = lgb.LGBMClassifier(**param)
    
    # クロスバリデーションの設定
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = []

    for train_idx, val_idx in kf.split(X_train):
        model.fit(
            X_train.iloc[train_idx], y_train.iloc[train_idx],
            eval_set=[(X_train.iloc[val_idx], y_train.iloc[val_idx])],
            callbacks=[early_stopping(stopping_rounds=100, verbose=False)]
        )
        preds = model.predict(X_train.iloc[val_idx])
        scores.append(accuracy_score(y_train.iloc[val_idx], preds))
    
    return np.mean(scores)

# Optunaによるパラメータ探索の実行
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)  # n_trialsを増加してより多くの試行を行う

# 最適なパラメータの出力
print("Best parameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# [I 2024-11-28 01:12:01,499] A new study created in memory with name: no-name-2846bf69-5dae-4227-8a3a-120a37f4159d
# [I 2024-11-28 01:12:24,676] Trial 0 finished with value: 0.5373944680171995 and parameters: {'n_estimators': 624, 'max_depth': 13, 'learning_rate': 0.0016709291205844472, 'num_leaves': 241, 'max_bin': 297, 'min_child_samples': 18, 'min_child_weight': 4.834028597872067, 'min_split_gain': 0.492267278776785, 'subsample': 0.8879749655325766, 'subsample_freq': 10, 'colsample_bytree': 0.691648751046346, 'reg_alpha': 0.7785187915586879, 'reg_lambda': 0.7595354058417261, 'feature_fraction': 0.721800267591437, 'bagging_fraction': 0.5255931549325985, 'lambda_l1': 4.245690915082988, 'lambda_l2': 0.7653910666525982}. Best is trial 0 with value: 0.5373944680171995.
# [I 2024-11-28 01:12:40,602] Trial 1 finished with value: 0.5416475698356535 and parameters: {'n_estimators': 1020, 'max_depth': 6, 'learning_rate': 0.002881677770381245, 'num_leaves': 186, 'max_bin': 232, 'min_child_samples': 21, 'min_child_weight': 9.592094994258835, 'min_split_gain': 0.40097226146250986, 'subsample': 0.8254890650596198, 'subsample_freq': 2, 'colsample_bytree': 0.7070818959828036, 'reg_alpha': 0.3353155623065631, 'reg_lambda': 0.8630616332654425, 'feature_fraction': 0.6774135812219545, 'bagging_fraction': 0.8404873414422667, 'lambda_l1': 4.212345139496506, 'lambda_l2': 2.3811957944684585}. Best is trial 1 with value: 0.5416475698356535.
# [I 2024-11-28 01:12:49,341] Trial 2 finished with value: 0.5334551668306409 and parameters: {'n_estimators': 1074, 'max_depth': 13, 'learning_rate': 0.013096448515877606, 'num_leaves': 256, 'max_bin': 379, 'min_child_samples': 58, 'min_child_weight': 3.411189521364333, 'min_split_gain': 0.3931938816956804, 'subsample': 0.9993112012535939, 'subsample_freq': 10, 'colsample_bytree': 0.8367505335233874, 'reg_alpha': 0.4540757475211914, 'reg_lambda': 0.22596822336835742, 'feature_fraction': 0.8392749898260365, 'bagging_fraction': 0.9297705578342241, 'lambda_l1': 3.8915286412376853, 'lambda_l2': 0.41973326295691393}. Best is trial 1 with value: 0.5416475698356535.
# [I 2024-11-28 01:12:57,030] Trial 3 finished with value: 0.5429322156168533 and parameters: {'n_estimators': 518, 'max_depth': 12, 'learning_rate': 0.004227159461918254, 'num_leaves': 27, 'max_bin': 466, 'min_child_samples': 88, 'min_child_weight': 7.3774849549844665, 'min_split_gain': 0.4270029858400829, 'subsample': 0.5237376099429327, 'subsample_freq': 4, 'colsample_bytree': 0.9593599308969613, 'reg_alpha': 0.2820921579514565, 'reg_lambda': 0.4018434478364594, 'feature_fraction': 0.6164695497934156, 'bagging_fraction': 0.6626035343504192, 'lambda_l1': 0.4587630354650335, 'lambda_l2': 2.4925059045951836}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:13:07,704] Trial 4 finished with value: 0.5412194713650609 and parameters: {'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.0021796238724988187, 'num_leaves': 138, 'max_bin': 347, 'min_child_samples': 80, 'min_child_weight': 4.514028701835983, 'min_split_gain': 0.3143187492850872, 'subsample': 0.535506812720683, 'subsample_freq': 1, 'colsample_bytree': 0.6670335338494097, 'reg_alpha': 0.09907363705168504, 'reg_lambda': 0.489917501729877, 'feature_fraction': 0.9574178352167262, 'bagging_fraction': 0.7040694639349416, 'lambda_l1': 1.9235433477255786, 'lambda_l2': 2.331472779235369}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:13:11,554] Trial 5 finished with value: 0.5339403632947942 and parameters: {'n_estimators': 1438, 'max_depth': 10, 'learning_rate': 0.05599285275490872, 'num_leaves': 186, 'max_bin': 290, 'min_child_samples': 57, 'min_child_weight': 9.150711716272376, 'min_split_gain': 0.12132733612520996, 'subsample': 0.5739947047896011, 'subsample_freq': 5, 'colsample_bytree': 0.8327163864258278, 'reg_alpha': 0.09597125573270149, 'reg_lambda': 0.8544213644586801, 'feature_fraction': 0.7270994255234546, 'bagging_fraction': 0.9904567041987677, 'lambda_l1': 4.177317166742482, 'lambda_l2': 1.7434638797112378}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:13:34,969] Trial 6 finished with value: 0.5428750361420318 and parameters: {'n_estimators': 1177, 'max_depth': 12, 'learning_rate': 0.0023504043773174134, 'num_leaves': 67, 'max_bin': 334, 'min_child_samples': 48, 'min_child_weight': 4.640771183707161, 'min_split_gain': 0.29673152763212274, 'subsample': 0.7803208085107809, 'subsample_freq': 3, 'colsample_bytree': 0.7985390781624897, 'reg_alpha': 0.3927483652036151, 'reg_lambda': 0.4644504617300247, 'feature_fraction': 0.7854208558673298, 'bagging_fraction': 0.786318478621251, 'lambda_l1': 3.7883973343866733, 'lambda_l2': 0.2762824581967066}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:13:38,623] Trial 7 finished with value: 0.5410767161960017 and parameters: {'n_estimators': 203, 'max_depth': 7, 'learning_rate': 0.0065290815511065544, 'num_leaves': 139, 'max_bin': 204, 'min_child_samples': 72, 'min_child_weight': 9.070696074460042, 'min_split_gain': 0.28889201025379657, 'subsample': 0.530525734376016, 'subsample_freq': 7, 'colsample_bytree': 0.888311254090377, 'reg_alpha': 0.061929214781873965, 'reg_lambda': 0.8432263947530285, 'feature_fraction': 0.5427444386636282, 'bagging_fraction': 0.7303758969135035, 'lambda_l1': 4.936113275723938, 'lambda_l2': 3.0667300751984805}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:14:02,539] Trial 8 finished with value: 0.5374800803780047 and parameters: {'n_estimators': 1334, 'max_depth': 15, 'learning_rate': 0.003838031609893267, 'num_leaves': 128, 'max_bin': 476, 'min_child_samples': 59, 'min_child_weight': 9.435032071123544, 'min_split_gain': 0.26084203937825395, 'subsample': 0.703523940241929, 'subsample_freq': 3, 'colsample_bytree': 0.6142536235404791, 'reg_alpha': 0.7766708669501889, 'reg_lambda': 0.5308775979442762, 'feature_fraction': 0.7243235008943072, 'bagging_fraction': 0.9673616886243119, 'lambda_l1': 2.9762237766118576, 'lambda_l2': 2.650980287504802}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:14:59,850] Trial 9 finished with value: 0.5396493763566885 and parameters: {'n_estimators': 1210, 'max_depth': 18, 'learning_rate': 0.0011799753090987828, 'num_leaves': 145, 'max_bin': 451, 'min_child_samples': 97, 'min_child_weight': 8.47309723034844, 'min_split_gain': 0.17827926827310692, 'subsample': 0.8126662290830935, 'subsample_freq': 3, 'colsample_bytree': 0.7129143754179638, 'reg_alpha': 0.22050186053017273, 'reg_lambda': 0.07735929110232864, 'feature_fraction': 0.7857389710915532, 'bagging_fraction': 0.8582790302746841, 'lambda_l1': 4.631682159710641, 'lambda_l2': 2.4213656091313736}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:15:03,177] Trial 10 finished with value: 0.5394496331937708 and parameters: {'n_estimators': 640, 'max_depth': 20, 'learning_rate': 0.018600159761855254, 'num_leaves': 29, 'max_bin': 420, 'min_child_samples': 99, 'min_child_weight': 6.879222213287564, 'min_split_gain': 0.0004795754498855831, 'subsample': 0.6819902668878975, 'subsample_freq': 6, 'colsample_bytree': 0.9978174849315162, 'reg_alpha': 0.6145380240864463, 'reg_lambda': 0.2826279098867135, 'feature_fraction': 0.5050309439290573, 'bagging_fraction': 0.5960139367058672, 'lambda_l1': 0.29635128509830233, 'lambda_l2': 4.59597986003307}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:15:10,247] Trial 11 finished with value: 0.5427323543061074 and parameters: {'n_estimators': 751, 'max_depth': 16, 'learning_rate': 0.007254741224600266, 'num_leaves': 21, 'max_bin': 361, 'min_child_samples': 36, 'min_child_weight': 0.025931830833440195, 'min_split_gain': 0.4991530724015366, 'subsample': 0.6653965877321997, 'subsample_freq': 4, 'colsample_bytree': 0.9941212249206945, 'reg_alpha': 0.4966836218144954, 'reg_lambda': 0.5064909408450262, 'feature_fraction': 0.6146976389394531, 'bagging_fraction': 0.6658314983209691, 'lambda_l1': 0.024467665036192077, 'lambda_l2': 3.929663145104127}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:15:25,698] Trial 12 finished with value: 0.5407912343763247 and parameters: {'n_estimators': 466, 'max_depth': 11, 'learning_rate': 0.003597394413149573, 'num_leaves': 65, 'max_bin': 496, 'min_child_samples': 39, 'min_child_weight': 6.67253424568208, 'min_split_gain': 0.3909743290658194, 'subsample': 0.6178885037973414, 'subsample_freq': 7, 'colsample_bytree': 0.5047414201639505, 'reg_alpha': 0.3042152103044696, 'reg_lambda': 0.35140537945915157, 'feature_fraction': 0.8591856057368288, 'bagging_fraction': 0.7816699134638126, 'lambda_l1': 1.2435938568613145, 'lambda_l2': 1.1980814887003892}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:15:51,369] Trial 13 finished with value: 0.5425611214363713 and parameters: {'n_estimators': 887, 'max_depth': 15, 'learning_rate': 0.001068691711668993, 'num_leaves': 75, 'max_bin': 408, 'min_child_samples': 79, 'min_child_weight': 2.503481182330828, 'min_split_gain': 0.1761215646398079, 'subsample': 0.7725596393151657, 'subsample_freq': 4, 'colsample_bytree': 0.9112880737394567, 'reg_alpha': 0.9586200416230332, 'reg_lambda': 0.6184030868675201, 'feature_fraction': 0.6086365158131275, 'bagging_fraction': 0.6282625668931605, 'lambda_l1': 3.0588929710293606, 'lambda_l2': 0.18922812063179606}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:15:55,878] Trial 14 finished with value: 0.5403915687917157 and parameters: {'n_estimators': 446, 'max_depth': 8, 'learning_rate': 0.02755196326361898, 'num_leaves': 68, 'max_bin': 315, 'min_child_samples': 40, 'min_child_weight': 6.631584386535172, 'min_split_gain': 0.34123551693125115, 'subsample': 0.9052290222433563, 'subsample_freq': 1, 'colsample_bytree': 0.7971909226757773, 'reg_alpha': 0.37799164918323164, 'reg_lambda': 0.6681765228167302, 'feature_fraction': 0.9570829909164549, 'bagging_fraction': 0.7875569117151946, 'lambda_l1': 1.2625478723302548, 'lambda_l2': 3.3930465876680613}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:16:02,024] Trial 15 finished with value: 0.5426752807569251 and parameters: {'n_estimators': 1005, 'max_depth': 4, 'learning_rate': 0.005244746855111342, 'num_leaves': 92, 'max_bin': 273, 'min_child_samples': 73, 'min_child_weight': 7.623433938896861, 'min_split_gain': 0.4306622593270537, 'subsample': 0.741375885662666, 'subsample_freq': 5, 'colsample_bytree': 0.9081214686885328, 'reg_alpha': 0.6354645051384268, 'reg_lambda': 0.3770542272917681, 'feature_fraction': 0.6565361547533128, 'bagging_fraction': 0.574542016467342, 'lambda_l1': 3.0311864285732555, 'lambda_l2': 1.6771563340714755}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:16:10,048] Trial 16 finished with value: 0.5419900600195042 and parameters: {'n_estimators': 1223, 'max_depth': 12, 'learning_rate': 0.010145798846357785, 'num_leaves': 46, 'max_bin': 410, 'min_child_samples': 46, 'min_child_weight': 5.651389042198282, 'min_split_gain': 0.19044217300401434, 'subsample': 0.6079711601788538, 'subsample_freq': 3, 'colsample_bytree': 0.7769539524052638, 'reg_alpha': 0.21123731318921452, 'reg_lambda': 0.07460058201685016, 'feature_fraction': 0.8128073066689754, 'bagging_fraction': 0.8553996208456399, 'lambda_l1': 2.2097755865078796, 'lambda_l2': 4.075833160156597}. Best is trial 3 with value: 0.5429322156168533.
# [I 2024-11-28 01:16:40,990] Trial 17 finished with value: 0.5431889752920707 and parameters: {'n_estimators': 852, 'max_depth': 14, 'learning_rate': 0.0017609932075076864, 'num_leaves': 100, 'max_bin': 326, 'min_child_samples': 30, 'min_child_weight': 1.7978148839060313, 'min_split_gain': 0.3427997547808007, 'subsample': 0.8678977535860583, 'subsample_freq': 8, 'colsample_bytree': 0.9455904173266103, 'reg_alpha': 0.59744427675402, 'reg_lambda': 0.17262350389866993, 'feature_fraction': 0.874552533471115, 'bagging_fraction': 0.6910773235567628, 'lambda_l1': 3.5134822439778723, 'lambda_l2': 1.276653279231773}. Best is trial 17 with value: 0.5431889752920707.
# [I 2024-11-28 01:17:13,025] Trial 18 finished with value: 0.541333663278119 and parameters: {'n_estimators': 771, 'max_depth': 17, 'learning_rate': 0.0013937767516071615, 'num_leaves': 103, 'max_bin': 251, 'min_child_samples': 10, 'min_child_weight': 0.6599781340454476, 'min_split_gain': 0.43928763431538626, 'subsample': 0.9676377285275661, 'subsample_freq': 8, 'colsample_bytree': 0.9488988142228697, 'reg_alpha': 0.5949794687872265, 'reg_lambda': 0.20723190139622572, 'feature_fraction': 0.8952767295793059, 'bagging_fraction': 0.6701482341592765, 'lambda_l1': 0.6256886770560472, 'lambda_l2': 1.6064212938812197}. Best is trial 17 with value: 0.5431889752920707.
# [I 2024-11-28 01:17:17,747] Trial 19 finished with value: 0.5315138717161474 and parameters: {'n_estimators': 534, 'max_depth': 14, 'learning_rate': 0.08460130753074718, 'num_leaves': 107, 'max_bin': 436, 'min_child_samples': 27, 'min_child_weight': 1.7870609317761135, 'min_split_gain': 0.3445668345242951, 'subsample': 0.8944864139072201, 'subsample_freq': 9, 'colsample_bytree': 0.9461374447921815, 'reg_alpha': 0.7722490486170396, 'reg_lambda': 0.14979282740963507, 'feature_fraction': 0.9115214108960217, 'bagging_fraction': 0.5262073711072452, 'lambda_l1': 1.710481248547648, 'lambda_l2': 1.0883579405905097}. Best is trial 17 with value: 0.5431889752920707.
# [I 2024-11-28 01:17:35,305] Trial 20 finished with value: 0.538736032533186 and parameters: {'n_estimators': 863, 'max_depth': 19, 'learning_rate': 0.004418595252836134, 'num_leaves': 166, 'max_bin': 374, 'min_child_samples': 88, 'min_child_weight': 3.0722369395130658, 'min_split_gain': 0.2284155326291628, 'subsample': 0.8302543563233883, 'subsample_freq': 8, 'colsample_bytree': 0.877609394764528, 'reg_alpha': 0.18856439566294458, 'reg_lambda': 0.35483086022875976, 'feature_fraction': 0.5806049531504291, 'bagging_fraction': 0.6432297100862987, 'lambda_l1': 2.6227041620936955, 'lambda_l2': 2.9692666186217083}. Best is trial 17 with value: 0.5431889752920707.
# [I 2024-11-28 01:18:00,584] Trial 21 finished with value: 0.5433031957235701 and parameters: {'n_estimators': 1493, 'max_depth': 12, 'learning_rate': 0.002024635881265135, 'num_leaves': 47, 'max_bin': 348, 'min_child_samples': 47, 'min_child_weight': 3.991262965610241, 'min_split_gain': 0.3550095097891059, 'subsample': 0.7920890917643145, 'subsample_freq': 4, 'colsample_bytree': 0.9387621856157179, 'reg_alpha': 0.4244801520046907, 'reg_lambda': 0.4200585628973752, 'feature_fraction': 0.7883783830705504, 'bagging_fraction': 0.763332603468799, 'lambda_l1': 3.61970170393704, 'lambda_l2': 0.5939814581139684}. Best is trial 21 with value: 0.5433031957235701.
# [I 2024-11-28 01:18:25,092] Trial 22 finished with value: 0.5440740410439853 and parameters: {'n_estimators': 1409, 'max_depth': 10, 'learning_rate': 0.001963602942755169, 'num_leaves': 42, 'max_bin': 320, 'min_child_samples': 29, 'min_child_weight': 1.5508384466447827, 'min_split_gain': 0.35028172061775315, 'subsample': 0.8497437832807306, 'subsample_freq': 6, 'colsample_bytree': 0.9393315943896063, 'reg_alpha': 0.510796059408923, 'reg_lambda': 0.030115142689989854, 'feature_fraction': 0.7709401565921447, 'bagging_fraction': 0.7265189777661054, 'lambda_l1': 3.732025232190374, 'lambda_l2': 0.7426305006484468}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:18:51,646] Trial 23 finished with value: 0.5434174528216371 and parameters: {'n_estimators': 1468, 'max_depth': 10, 'learning_rate': 0.001997824137488934, 'num_leaves': 52, 'max_bin': 305, 'min_child_samples': 31, 'min_child_weight': 1.1977640296391008, 'min_split_gain': 0.3484011877855728, 'subsample': 0.9289733504649517, 'subsample_freq': 6, 'colsample_bytree': 0.8512538153805801, 'reg_alpha': 0.5490981559707474, 'reg_lambda': 0.0020294804765413933, 'feature_fraction': 0.8871099956465379, 'bagging_fraction': 0.7403456644528941, 'lambda_l1': 3.497705706248613, 'lambda_l2': 0.7898416757192801}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:19:15,365] Trial 24 finished with value: 0.543017795385154 and parameters: {'n_estimators': 1428, 'max_depth': 10, 'learning_rate': 0.002467947699861434, 'num_leaves': 47, 'max_bin': 303, 'min_child_samples': 30, 'min_child_weight': 1.343833183420126, 'min_split_gain': 0.3534120957687445, 'subsample': 0.9433712399282997, 'subsample_freq': 6, 'colsample_bytree': 0.84987384237459, 'reg_alpha': 0.5170532580069759, 'reg_lambda': 0.05129683798834317, 'feature_fraction': 0.7868629845379219, 'bagging_fraction': 0.7508334692445429, 'lambda_l1': 3.5156313502443, 'lambda_l2': 0.7198905213499438}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:19:42,153] Trial 25 finished with value: 0.5431034321903374 and parameters: {'n_estimators': 1497, 'max_depth': 9, 'learning_rate': 0.0018642275915445648, 'num_leaves': 50, 'max_bin': 269, 'min_child_samples': 50, 'min_child_weight': 3.1681947631217287, 'min_split_gain': 0.2431731250408641, 'subsample': 0.9403452257464165, 'subsample_freq': 6, 'colsample_bytree': 0.8849545604475075, 'reg_alpha': 0.6942595856360797, 'reg_lambda': 0.01420971158406955, 'feature_fraction': 0.9126911527282743, 'bagging_fraction': 0.7590768194822303, 'lambda_l1': 3.3500945731041076, 'lambda_l2': 0.6734089894113131}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:20:03,450] Trial 26 finished with value: 0.5440168534210376 and parameters: {'n_estimators': 1345, 'max_depth': 5, 'learning_rate': 0.0010458456209726887, 'num_leaves': 41, 'max_bin': 382, 'min_child_samples': 20, 'min_child_weight': 3.974074386802637, 'min_split_gain': 0.46332625351416085, 'subsample': 0.8528017452468176, 'subsample_freq': 5, 'colsample_bytree': 0.8528107030568545, 'reg_alpha': 0.4458396754177574, 'reg_lambda': 0.9772887802155777, 'feature_fraction': 0.83393220774051, 'bagging_fraction': 0.8158459526625473, 'lambda_l1': 4.681722799542618, 'lambda_l2': 0.030854823282150612}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:20:35,696] Trial 27 finished with value: 0.5434174080069435 and parameters: {'n_estimators': 1319, 'max_depth': 4, 'learning_rate': 0.0010548057698851906, 'num_leaves': 83, 'max_bin': 389, 'min_child_samples': 12, 'min_child_weight': 1.034669790823639, 'min_split_gain': 0.44851199588234514, 'subsample': 0.8518172502587549, 'subsample_freq': 7, 'colsample_bytree': 0.7558428146531229, 'reg_alpha': 0.5231348322084746, 'reg_lambda': 0.9178880378460252, 'feature_fraction': 0.994344758587887, 'bagging_fraction': 0.8306094943635708, 'lambda_l1': 4.681018694163886, 'lambda_l2': 0.014082663761819547}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:21:01,270] Trial 28 finished with value: 0.5423897622706807 and parameters: {'n_estimators': 1360, 'max_depth': 6, 'learning_rate': 0.00291573794318357, 'num_leaves': 116, 'max_bin': 336, 'min_child_samples': 21, 'min_child_weight': 2.4099298079720457, 'min_split_gain': 0.46908308327178516, 'subsample': 0.928127169675665, 'subsample_freq': 5, 'colsample_bytree': 0.8556274871085414, 'reg_alpha': 0.9094781949838544, 'reg_lambda': 0.9969885122003547, 'feature_fraction': 0.830141727931157, 'bagging_fraction': 0.9100023121971135, 'lambda_l1': 4.512492486272166, 'lambda_l2': 1.051847710488246}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:21:25,630] Trial 29 finished with value: 0.5425609951404169 and parameters: {'n_estimators': 1132, 'max_depth': 6, 'learning_rate': 0.001469865769902245, 'num_leaves': 37, 'max_bin': 288, 'min_child_samples': 16, 'min_child_weight': 5.735716806335534, 'min_split_gain': 0.4772590324504378, 'subsample': 0.8645445930222542, 'subsample_freq': 6, 'colsample_bytree': 0.8075440800801268, 'reg_alpha': 0.67384129647281, 'reg_lambda': 0.7186175287289123, 'feature_fraction': 0.7527630154248723, 'bagging_fraction': 0.8179132305967702, 'lambda_l1': 4.071153209354451, 'lambda_l2': 2.047085266782387}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:21:46,439] Trial 30 finished with value: 0.5421614191851948 and parameters: {'n_estimators': 1292, 'max_depth': 5, 'learning_rate': 0.0014375038088513701, 'num_leaves': 56, 'max_bin': 307, 'min_child_samples': 26, 'min_child_weight': 0.15492236313525165, 'min_split_gain': 0.38302518025080695, 'subsample': 0.9781913166559277, 'subsample_freq': 7, 'colsample_bytree': 0.9107675338622975, 'reg_alpha': 0.5493007346048879, 'reg_lambda': 0.12258849493278146, 'feature_fraction': 0.6792294646683119, 'bagging_fraction': 0.7111140996683255, 'lambda_l1': 2.6107465843737336, 'lambda_l2': 0.9210864758350784}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:22:06,119] Trial 31 finished with value: 0.5431319832241492 and parameters: {'n_estimators': 1281, 'max_depth': 4, 'learning_rate': 0.001029729297912667, 'num_leaves': 80, 'max_bin': 386, 'min_child_samples': 10, 'min_child_weight': 1.1174927578239502, 'min_split_gain': 0.45594184436473123, 'subsample': 0.8551438488297525, 'subsample_freq': 7, 'colsample_bytree': 0.7372501559606639, 'reg_alpha': 0.45784977148004385, 'reg_lambda': 0.97392302470727, 'feature_fraction': 0.9793898110963511, 'bagging_fraction': 0.891345079582956, 'lambda_l1': 4.978799145860509, 'lambda_l2': 0.12173389603117557}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:22:55,356] Trial 32 finished with value: 0.5439883390537933 and parameters: {'n_estimators': 1376, 'max_depth': 7, 'learning_rate': 0.0010131547014262687, 'num_leaves': 76, 'max_bin': 397, 'min_child_samples': 17, 'min_child_weight': 2.1478760024078625, 'min_split_gain': 0.40986982136537353, 'subsample': 0.8376187430564033, 'subsample_freq': 9, 'colsample_bytree': 0.6512475510970142, 'reg_alpha': 0.5227105905556969, 'reg_lambda': 0.9265138360002898, 'feature_fraction': 0.9349207589942247, 'bagging_fraction': 0.810870871264013, 'lambda_l1': 4.49887650066515, 'lambda_l2': 0.08675924596157306}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:23:40,477] Trial 33 finished with value: 0.5433318323127059 and parameters: {'n_estimators': 1411, 'max_depth': 8, 'learning_rate': 0.0015509868591330107, 'num_leaves': 220, 'max_bin': 365, 'min_child_samples': 21, 'min_child_weight': 1.9420381015933623, 'min_split_gain': 0.41199819210453786, 'subsample': 0.9055554928182831, 'subsample_freq': 10, 'colsample_bytree': 0.6180209570619921, 'reg_alpha': 0.3554487269356719, 'reg_lambda': 0.7674310658813204, 'feature_fraction': 0.9476460725317739, 'bagging_fraction': 0.817478511346126, 'lambda_l1': 4.3671103383873815, 'lambda_l2': 0.38011280088765176}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:24:00,064] Trial 34 finished with value: 0.541219300254413 and parameters: {'n_estimators': 1048, 'max_depth': 7, 'learning_rate': 0.0030555507705077355, 'num_leaves': 58, 'max_bin': 401, 'min_child_samples': 17, 'min_child_weight': 3.872206339823552, 'min_split_gain': 0.3800647993465859, 'subsample': 0.7368176481665726, 'subsample_freq': 9, 'colsample_bytree': 0.675398296713987, 'reg_alpha': 0.45905094797355395, 'reg_lambda': 0.9111100985025626, 'feature_fraction': 0.8592857567155594, 'bagging_fraction': 0.881310491363986, 'lambda_l1': 3.918065819041934, 'lambda_l2': 0.5035880473442378}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:24:24,501] Trial 35 finished with value: 0.5426181216524188 and parameters: {'n_estimators': 1397, 'max_depth': 10, 'learning_rate': 0.0014225888775090578, 'num_leaves': 23, 'max_bin': 429, 'min_child_samples': 34, 'min_child_weight': 2.5539587334954894, 'min_split_gain': 0.30664495209269355, 'subsample': 0.8269996536033967, 'subsample_freq': 9, 'colsample_bytree': 0.6344648159903168, 'reg_alpha': 0.699578955443094, 'reg_lambda': 0.005268930319739518, 'feature_fraction': 0.9276192467266103, 'bagging_fraction': 0.725163524239496, 'lambda_l1': 4.278520642508072, 'lambda_l2': 1.4145908036666905}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:24:44,911] Trial 36 finished with value: 0.542732313565477 and parameters: {'n_estimators': 1105, 'max_depth': 8, 'learning_rate': 0.002197790541065063, 'num_leaves': 39, 'max_bin': 320, 'min_child_samples': 18, 'min_child_weight': 0.7452248442180873, 'min_split_gain': 0.41790474363605257, 'subsample': 0.882675681701734, 'subsample_freq': 5, 'colsample_bytree': 0.5909776246050468, 'reg_alpha': 0.5490323668240108, 'reg_lambda': 0.5942020457917788, 'feature_fraction': 0.8836472095243096, 'bagging_fraction': 0.8044371037820647, 'lambda_l1': 4.749132081564749, 'lambda_l2': 0.4387723925321515}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:25:00,692] Trial 37 finished with value: 0.5431604772210784 and parameters: {'n_estimators': 1255, 'max_depth': 6, 'learning_rate': 0.0028450103996908007, 'num_leaves': 35, 'max_bin': 361, 'min_child_samples': 30, 'min_child_weight': 3.6973027726339467, 'min_split_gain': 0.3748255558746543, 'subsample': 0.8057873517632592, 'subsample_freq': 5, 'colsample_bytree': 0.5458631431070811, 'reg_alpha': 0.41338214917959365, 'reg_lambda': 0.2769742219178949, 'feature_fraction': 0.8450032807258038, 'bagging_fraction': 0.7385953453609067, 'lambda_l1': 3.9953726009396977, 'lambda_l2': 0.8526898721500249}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:25:26,769] Trial 38 finished with value: 0.5430463464189659 and parameters: {'n_estimators': 942, 'max_depth': 9, 'learning_rate': 0.0010043028843278003, 'num_leaves': 84, 'max_bin': 236, 'min_child_samples': 25, 'min_child_weight': 5.078598620450075, 'min_split_gain': 0.4052307871752839, 'subsample': 0.9223049488649552, 'subsample_freq': 10, 'colsample_bytree': 0.8289494450914572, 'reg_alpha': 0.3053447816542909, 'reg_lambda': 0.8002061473093026, 'feature_fraction': 0.7455917645932147, 'bagging_fraction': 0.6917938863715762, 'lambda_l1': 4.427456740915943, 'lambda_l2': 2.010372495463603}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:26:00,381] Trial 39 finished with value: 0.542475390927738 and parameters: {'n_estimators': 1492, 'max_depth': 11, 'learning_rate': 0.0018710217379017283, 'num_leaves': 67, 'max_bin': 342, 'min_child_samples': 42, 'min_child_weight': 2.867583925323403, 'min_split_gain': 0.3265673837003996, 'subsample': 0.9993631685897189, 'subsample_freq': 2, 'colsample_bytree': 0.7203629598161415, 'reg_alpha': 0.8253861113094211, 'reg_lambda': 0.9262391425375063, 'feature_fraction': 0.8192791919874283, 'bagging_fraction': 0.9511508131192407, 'lambda_l1': 3.245872974879995, 'lambda_l2': 0.023868556525494383}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:26:04,545] Trial 40 finished with value: 0.5407341078643227 and parameters: {'n_estimators': 1159, 'max_depth': 7, 'learning_rate': 0.03139128936646522, 'num_leaves': 122, 'max_bin': 278, 'min_child_samples': 34, 'min_child_weight': 2.0893819671887592, 'min_split_gain': 0.2724750611009558, 'subsample': 0.7656540509010443, 'subsample_freq': 4, 'colsample_bytree': 0.7572259440353696, 'reg_alpha': 0.455979316024707, 'reg_lambda': 0.7185190702839834, 'feature_fraction': 0.933099245580984, 'bagging_fraction': 0.8468465928562401, 'lambda_l1': 4.220356882351036, 'lambda_l2': 0.24059571095924034}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:26:27,452] Trial 41 finished with value: 0.5433602570505632 and parameters: {'n_estimators': 1349, 'max_depth': 5, 'learning_rate': 0.0012386596011021668, 'num_leaves': 89, 'max_bin': 389, 'min_child_samples': 14, 'min_child_weight': 1.423192125728557, 'min_split_gain': 0.44984432767187904, 'subsample': 0.8443494520989812, 'subsample_freq': 6, 'colsample_bytree': 0.6873474437970889, 'reg_alpha': 0.5172494752095345, 'reg_lambda': 0.8962238774147584, 'feature_fraction': 0.9859496156109335, 'bagging_fraction': 0.8294891739609003, 'lambda_l1': 4.78006499391965, 'lambda_l2': 0.03192753770604307}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:26:48,914] Trial 42 finished with value: 0.5436742165709173 and parameters: {'n_estimators': 1322, 'max_depth': 5, 'learning_rate': 0.0012474312869387716, 'num_leaves': 59, 'max_bin': 368, 'min_child_samples': 13, 'min_child_weight': 0.69454842234849, 'min_split_gain': 0.47850634480236065, 'subsample': 0.8818154012310826, 'subsample_freq': 7, 'colsample_bytree': 0.7468252830553203, 'reg_alpha': 0.5557610998028681, 'reg_lambda': 0.8229464754861513, 'feature_fraction': 0.9947014954123315, 'bagging_fraction': 0.7868135934603455, 'lambda_l1': 3.7926168555038724, 'lambda_l2': 0.3902253006817053}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:27:10,444] Trial 43 finished with value: 0.5437885184836777 and parameters: {'n_estimators': 1391, 'max_depth': 5, 'learning_rate': 0.0016489864239174832, 'num_leaves': 57, 'max_bin': 372, 'min_child_samples': 20, 'min_child_weight': 0.5908394094646875, 'min_split_gain': 0.48273657753693816, 'subsample': 0.88302278569244, 'subsample_freq': 8, 'colsample_bytree': 0.9753629579552792, 'reg_alpha': 0.5636002097951264, 'reg_lambda': 0.8225369083367069, 'feature_fraction': 0.9697469361461092, 'bagging_fraction': 0.7809200061546215, 'lambda_l1': 3.7708698609720126, 'lambda_l2': 0.8163896383086549}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:27:29,685] Trial 44 finished with value: 0.5440453840845342 and parameters: {'n_estimators': 1375, 'max_depth': 5, 'learning_rate': 0.0016428418272396589, 'num_leaves': 20, 'max_bin': 370, 'min_child_samples': 22, 'min_child_weight': 0.6051388134621258, 'min_split_gain': 0.4875517004275909, 'subsample': 0.8803238625943058, 'subsample_freq': 8, 'colsample_bytree': 0.9765283597729533, 'reg_alpha': 0.6480792772485642, 'reg_lambda': 0.8344942904516462, 'feature_fraction': 0.9820001607244794, 'bagging_fraction': 0.7880007725456369, 'lambda_l1': 3.7644246385556013, 'lambda_l2': 0.36413335838726224}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:27:44,778] Trial 45 finished with value: 0.5438169350734091 and parameters: {'n_estimators': 1209, 'max_depth': 5, 'learning_rate': 0.0026446625523250267, 'num_leaves': 31, 'max_bin': 399, 'min_child_samples': 22, 'min_child_weight': 0.3881004350624213, 'min_split_gain': 0.49585117461263384, 'subsample': 0.8062746184782569, 'subsample_freq': 8, 'colsample_bytree': 0.9722542284871954, 'reg_alpha': 0.6386731463038745, 'reg_lambda': 0.8671078415036841, 'feature_fraction': 0.9555599782515996, 'bagging_fraction': 0.8734758794673784, 'lambda_l1': 3.78366178299612, 'lambda_l2': 0.5922554428993625}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:27:57,117] Trial 46 finished with value: 0.5423612479034363 and parameters: {'n_estimators': 1220, 'max_depth': 6, 'learning_rate': 0.003690706000721694, 'num_leaves': 35, 'max_bin': 445, 'min_child_samples': 23, 'min_child_weight': 0.3005312912821867, 'min_split_gain': 0.4942536985005674, 'subsample': 0.8054764421467158, 'subsample_freq': 9, 'colsample_bytree': 0.9808068648395066, 'reg_alpha': 0.6598677116071097, 'reg_lambda': 0.9613741745937175, 'feature_fraction': 0.7004802190388583, 'bagging_fraction': 0.924101392323663, 'lambda_l1': 2.806934539462632, 'lambda_l2': 0.2853462874074727}. Best is trial 22 with value: 0.5440740410439853.
# [I 2024-11-28 01:28:12,736] Trial 47 finished with value: 0.5453298383847709 and parameters: {'n_estimators': 1254, 'max_depth': 4, 'learning_rate': 0.002473379660036356, 'num_leaves': 23, 'max_bin': 397, 'min_child_samples': 24, 'min_child_weight': 4.286763092056577, 'min_split_gain': 0.4295113351239504, 'subsample': 0.8263179314839532, 'subsample_freq': 9, 'colsample_bytree': 0.9198582231110037, 'reg_alpha': 0.7374422190983096, 'reg_lambda': 0.8597683261219916, 'feature_fraction': 0.9502311051596816, 'bagging_fraction': 0.8685087113323089, 'lambda_l1': 4.553035857236106, 'lambda_l2': 0.46710238701551265}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:28:19,012] Trial 48 finished with value: 0.5443879638977718 and parameters: {'n_estimators': 1273, 'max_depth': 4, 'learning_rate': 0.006820724398485823, 'num_leaves': 22, 'max_bin': 419, 'min_child_samples': 62, 'min_child_weight': 4.444993586633358, 'min_split_gain': 0.42220556221088035, 'subsample': 0.8309287285748759, 'subsample_freq': 10, 'colsample_bytree': 0.9317146251555632, 'reg_alpha': 0.7417476905256857, 'reg_lambda': 0.7658834262904702, 'feature_fraction': 0.7538545323522808, 'bagging_fraction': 0.7997283446563462, 'lambda_l1': 4.513379423707804, 'lambda_l2': 1.3869719223110781}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:28:28,457] Trial 49 finished with value: 0.5425895583964179 and parameters: {'n_estimators': 1012, 'max_depth': 4, 'learning_rate': 0.005524000539794818, 'num_leaves': 22, 'max_bin': 458, 'min_child_samples': 63, 'min_child_weight': 4.3969420947650795, 'min_split_gain': 0.4319240373310428, 'subsample': 0.7100062894961658, 'subsample_freq': 10, 'colsample_bytree': 0.9259527229046858, 'reg_alpha': 0.753843484498397, 'reg_lambda': 0.7336202014175779, 'feature_fraction': 0.7557082287173352, 'bagging_fraction': 0.8681843601927258, 'lambda_l1': 4.958001077179611, 'lambda_l2': 1.3716932764098688}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:28:34,565] Trial 50 finished with value: 0.5437884492246059 and parameters: {'n_estimators': 1095, 'max_depth': 4, 'learning_rate': 0.008585824672243626, 'num_leaves': 21, 'max_bin': 480, 'min_child_samples': 64, 'min_child_weight': 5.332729797145259, 'min_split_gain': 0.4651199746171527, 'subsample': 0.762345932702076, 'subsample_freq': 10, 'colsample_bytree': 0.9244004837040262, 'reg_alpha': 0.824793274592833, 'reg_lambda': 0.6759478502186195, 'feature_fraction': 0.7086978447174147, 'bagging_fraction': 0.9008115596175346, 'lambda_l1': 4.094307490274438, 'lambda_l2': 1.102854948433937}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:28:39,677] Trial 51 finished with value: 0.5410196304246303 and parameters: {'n_estimators': 1377, 'max_depth': 7, 'learning_rate': 0.019095604181093816, 'num_leaves': 39, 'max_bin': 421, 'min_child_samples': 53, 'min_child_weight': 4.257577420153496, 'min_split_gain': 0.009614395275691912, 'subsample': 0.8372724438823158, 'subsample_freq': 9, 'colsample_bytree': 0.8954054600829043, 'reg_alpha': 0.7270397485085726, 'reg_lambda': 0.8673484563812968, 'feature_fraction': 0.7975668207244776, 'bagging_fraction': 0.8036025208931751, 'lambda_l1': 4.506836542824691, 'lambda_l2': 0.3072359601549032}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:28:45,123] Trial 52 finished with value: 0.5446734620137009 and parameters: {'n_estimators': 1256, 'max_depth': 6, 'learning_rate': 0.012519901110522657, 'num_leaves': 29, 'max_bin': 417, 'min_child_samples': 69, 'min_child_weight': 4.960164681469735, 'min_split_gain': 0.4129300069960873, 'subsample': 0.7891907220577393, 'subsample_freq': 9, 'colsample_bytree': 0.961183447002421, 'reg_alpha': 0.8426308680843553, 'reg_lambda': 0.9660814596216741, 'feature_fraction': 0.9350341754450339, 'bagging_fraction': 0.7670586773761058, 'lambda_l1': 4.606623501798942, 'lambda_l2': 0.5286853946846537}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:28:51,057] Trial 53 finished with value: 0.5416762430913566 and parameters: {'n_estimators': 1254, 'max_depth': 6, 'learning_rate': 0.010154813643246463, 'num_leaves': 29, 'max_bin': 356, 'min_child_samples': 68, 'min_child_weight': 6.0766971305060355, 'min_split_gain': 0.4323306611804918, 'subsample': 0.7840555328073784, 'subsample_freq': 10, 'colsample_bytree': 0.9636275894489916, 'reg_alpha': 0.8584946383981051, 'reg_lambda': 0.771173959258955, 'feature_fraction': 0.7650994205406925, 'bagging_fraction': 0.7682195065594155, 'lambda_l1': 4.767320595429207, 'lambda_l2': 0.9794206609100242}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:28:56,159] Trial 54 finished with value: 0.5443309596076612 and parameters: {'n_estimators': 1178, 'max_depth': 5, 'learning_rate': 0.01357361257745764, 'num_leaves': 42, 'max_bin': 415, 'min_child_samples': 71, 'min_child_weight': 4.87423098383594, 'min_split_gain': 0.3992668636516765, 'subsample': 0.8181191293005692, 'subsample_freq': 9, 'colsample_bytree': 0.9930913284384114, 'reg_alpha': 0.9043745719901217, 'reg_lambda': 0.9612020556311559, 'feature_fraction': 0.9696231164159721, 'bagging_fraction': 0.717779928640185, 'lambda_l1': 4.190355781009888, 'lambda_l2': 1.508565738793759}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:00,540] Trial 55 finished with value: 0.5447018948996846 and parameters: {'n_estimators': 1164, 'max_depth': 4, 'learning_rate': 0.014323363362564576, 'num_leaves': 20, 'max_bin': 413, 'min_child_samples': 75, 'min_child_weight': 3.4078727993483002, 'min_split_gain': 0.3975066917881331, 'subsample': 0.7233934823073321, 'subsample_freq': 9, 'colsample_bytree': 0.9964609235193479, 'reg_alpha': 0.9834962197921799, 'reg_lambda': 0.5572003027110148, 'feature_fraction': 0.9701425725190582, 'bagging_fraction': 0.7182678149016273, 'lambda_l1': 4.235970670703271, 'lambda_l2': 1.5436419811794084}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:04,835] Trial 56 finished with value: 0.5435315632534344 and parameters: {'n_estimators': 1183, 'max_depth': 4, 'learning_rate': 0.013321585525689413, 'num_leaves': 214, 'max_bin': 418, 'min_child_samples': 79, 'min_child_weight': 4.7986943439621745, 'min_split_gain': 0.39755014420735735, 'subsample': 0.7280721542899302, 'subsample_freq': 9, 'colsample_bytree': 0.99513976933426, 'reg_alpha': 0.9974644736580557, 'reg_lambda': 0.6128625180896486, 'feature_fraction': 0.9097397574906112, 'bagging_fraction': 0.7158809836511671, 'lambda_l1': 4.264687196736659, 'lambda_l2': 1.896127889383168}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:08,428] Trial 57 finished with value: 0.543645795907123 and parameters: {'n_estimators': 1161, 'max_depth': 4, 'learning_rate': 0.015821705695128484, 'num_leaves': 30, 'max_bin': 439, 'min_child_samples': 73, 'min_child_weight': 3.5364978724222595, 'min_split_gain': 0.37690660176747987, 'subsample': 0.6828796065237774, 'subsample_freq': 9, 'colsample_bytree': 0.9986490855724839, 'reg_alpha': 0.8872766222639593, 'reg_lambda': 0.5248212645202963, 'feature_fraction': 0.6566608817520632, 'bagging_fraction': 0.691393311286733, 'lambda_l1': 4.150988638890764, 'lambda_l2': 2.248913312153772}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:15,821] Trial 58 finished with value: 0.5394495394903208 and parameters: {'n_estimators': 971, 'max_depth': 13, 'learning_rate': 0.020037145367997035, 'num_leaves': 154, 'max_bin': 469, 'min_child_samples': 83, 'min_child_weight': 5.2560535479645845, 'min_split_gain': 0.3660354631329862, 'subsample': 0.7898476670455079, 'subsample_freq': 10, 'colsample_bytree': 0.9310979439604586, 'reg_alpha': 0.9536893430124703, 'reg_lambda': 0.5537475699082153, 'feature_fraction': 0.9668553762891562, 'bagging_fraction': 0.6779771530099133, 'lambda_l1': 4.544330337249425, 'lambda_l2': 1.5808020943238739}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:19,759] Trial 59 finished with value: 0.5423612519774993 and parameters: {'n_estimators': 1066, 'max_depth': 8, 'learning_rate': 0.027052504919469627, 'num_leaves': 48, 'max_bin': 413, 'min_child_samples': 70, 'min_child_weight': 6.066118286329687, 'min_split_gain': 0.31913508377323097, 'subsample': 0.7511779388966905, 'subsample_freq': 8, 'colsample_bytree': 0.9554164908988261, 'reg_alpha': 0.8058857327434081, 'reg_lambda': 0.4694507451257132, 'feature_fraction': 0.9467554854547167, 'bagging_fraction': 0.6258649340323197, 'lambda_l1': 4.324593444660977, 'lambda_l2': 1.5013811645936317}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:25,277] Trial 60 finished with value: 0.5426183090593188 and parameters: {'n_estimators': 1267, 'max_depth': 6, 'learning_rate': 0.012467046778469026, 'num_leaves': 42, 'max_bin': 454, 'min_child_samples': 59, 'min_child_weight': 4.672747594312351, 'min_split_gain': 0.3921304665701847, 'subsample': 0.8133596120952508, 'subsample_freq': 9, 'colsample_bytree': 0.9570072435498295, 'reg_alpha': 0.9214329487734292, 'reg_lambda': 0.3072447186926997, 'feature_fraction': 0.9003466297748797, 'bagging_fraction': 0.74675508580343, 'lambda_l1': 4.027537878115281, 'lambda_l2': 1.2316082698356845}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:31,446] Trial 61 finished with value: 0.5445590949159319 and parameters: {'n_estimators': 1437, 'max_depth': 5, 'learning_rate': 0.008032522734960275, 'num_leaves': 21, 'max_bin': 427, 'min_child_samples': 66, 'min_child_weight': 4.243965537842402, 'min_split_gain': 0.42093371682853864, 'subsample': 0.7130535930740334, 'subsample_freq': 8, 'colsample_bytree': 0.9004897300764476, 'reg_alpha': 0.8576162763128407, 'reg_lambda': 0.8119988326510957, 'feature_fraction': 0.973373161133944, 'bagging_fraction': 0.7295613141194169, 'lambda_l1': 3.623106946884162, 'lambda_l2': 1.8023421573438116}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:36,841] Trial 62 finished with value: 0.5439596250574597 and parameters: {'n_estimators': 1442, 'max_depth': 4, 'learning_rate': 0.00744012172841591, 'num_leaves': 29, 'max_bin': 426, 'min_child_samples': 76, 'min_child_weight': 4.127856272322974, 'min_split_gain': 0.4298846704575763, 'subsample': 0.6603514946551958, 'subsample_freq': 8, 'colsample_bytree': 0.8960036894907905, 'reg_alpha': 0.8650572053818533, 'reg_lambda': 0.9596877110784768, 'feature_fraction': 0.96332453569471, 'bagging_fraction': 0.6556583937355642, 'lambda_l1': 3.209769497366496, 'lambda_l2': 1.7904190037807033}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:41,415] Trial 63 finished with value: 0.5430177587185867 and parameters: {'n_estimators': 1290, 'max_depth': 5, 'learning_rate': 0.011174912284842927, 'num_leaves': 30, 'max_bin': 434, 'min_child_samples': 66, 'min_child_weight': 3.2801630523213974, 'min_split_gain': 0.4196022683641219, 'subsample': 0.7179315068710651, 'subsample_freq': 9, 'colsample_bytree': 0.918326224045614, 'reg_alpha': 0.9941033411662431, 'reg_lambda': 0.8843586010440755, 'feature_fraction': 0.9257063669004374, 'bagging_fraction': 0.7248313835063391, 'lambda_l1': 3.6201073086456477, 'lambda_l2': 2.126413199877906}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:46,502] Trial 64 finished with value: 0.544131159407861 and parameters: {'n_estimators': 1449, 'max_depth': 4, 'learning_rate': 0.008124053793260864, 'num_leaves': 44, 'max_bin': 407, 'min_child_samples': 62, 'min_child_weight': 4.934364119337296, 'min_split_gain': 0.35924820821069287, 'subsample': 0.643952290034752, 'subsample_freq': 10, 'colsample_bytree': 0.8717635912003486, 'reg_alpha': 0.9480040984463481, 'reg_lambda': 0.6555799970291929, 'feature_fraction': 0.998324487352837, 'bagging_fraction': 0.7054241613023035, 'lambda_l1': 3.9508964516448284, 'lambda_l2': 1.2874668511842708}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:51,042] Trial 65 finished with value: 0.544445017076639 and parameters: {'n_estimators': 1129, 'max_depth': 4, 'learning_rate': 0.008244958500861033, 'num_leaves': 21, 'max_bin': 404, 'min_child_samples': 61, 'min_child_weight': 4.500761752166478, 'min_split_gain': 0.3622693076847574, 'subsample': 0.6115891834802789, 'subsample_freq': 10, 'colsample_bytree': 0.8678032589329806, 'reg_alpha': 0.9455412732953677, 'reg_lambda': 0.6598525695854291, 'feature_fraction': 0.972758895289103, 'bagging_fraction': 0.7054538773421282, 'lambda_l1': 3.921021081682645, 'lambda_l2': 2.5857510682519798}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:29:59,214] Trial 66 finished with value: 0.5433889425284557 and parameters: {'n_estimators': 1214, 'max_depth': 5, 'learning_rate': 0.0059991011590362535, 'num_leaves': 20, 'max_bin': 445, 'min_child_samples': 58, 'min_child_weight': 4.458481697256723, 'min_split_gain': 0.4009818505200176, 'subsample': 0.6907319012117329, 'subsample_freq': 10, 'colsample_bytree': 0.9041866072235243, 'reg_alpha': 0.9219759389415494, 'reg_lambda': 0.7877254498152972, 'feature_fraction': 0.9455023889208765, 'bagging_fraction': 0.7628426790811179, 'lambda_l1': 4.841511653417385, 'lambda_l2': 2.5126051763407267}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:30:03,236] Trial 67 finished with value: 0.5431320239647797 and parameters: {'n_estimators': 1135, 'max_depth': 6, 'learning_rate': 0.016135626647504567, 'num_leaves': 26, 'max_bin': 411, 'min_child_samples': 55, 'min_child_weight': 5.36683820870533, 'min_split_gain': 0.4438440101399651, 'subsample': 0.6414566610093306, 'subsample_freq': 9, 'colsample_bytree': 0.8683646497549165, 'reg_alpha': 0.8573720773494542, 'reg_lambda': 0.6899741279388736, 'feature_fraction': 0.974507519587546, 'bagging_fraction': 0.6411516489432587, 'lambda_l1': 4.601661157220541, 'lambda_l2': 3.2449736483040548}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:30:09,720] Trial 68 finished with value: 0.540305907542154 and parameters: {'n_estimators': 688, 'max_depth': 4, 'learning_rate': 0.004325336962414161, 'num_leaves': 65, 'max_bin': 398, 'min_child_samples': 69, 'min_child_weight': 5.6743568625153005, 'min_split_gain': 0.28777578717337027, 'subsample': 0.5033235208970633, 'subsample_freq': 10, 'colsample_bytree': 0.9416760877541049, 'reg_alpha': 0.8003617418754666, 'reg_lambda': 0.6466512125362949, 'feature_fraction': 0.5293849857623003, 'bagging_fraction': 0.991175638953883, 'lambda_l1': 2.327102866867656, 'lambda_l2': 2.8928180267665904}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:30:14,194] Trial 69 finished with value: 0.543731404193865 and parameters: {'n_estimators': 915, 'max_depth': 5, 'learning_rate': 0.00919591456787211, 'num_leaves': 34, 'max_bin': 426, 'min_child_samples': 86, 'min_child_weight': 3.6068835576987612, 'min_split_gain': 0.3346863305916746, 'subsample': 0.542595711570554, 'subsample_freq': 9, 'colsample_bytree': 0.9837170251532336, 'reg_alpha': 0.8879211464751485, 'reg_lambda': 0.5597900948896678, 'feature_fraction': 0.9155956457945484, 'bagging_fraction': 0.6078339422718327, 'lambda_l1': 4.37293006796664, 'lambda_l2': 2.7173841849226865}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:30:21,140] Trial 70 finished with value: 0.5403916421248505 and parameters: {'n_estimators': 346, 'max_depth': 6, 'learning_rate': 0.00685142150110823, 'num_leaves': 50, 'max_bin': 482, 'min_child_samples': 74, 'min_child_weight': 2.8085239515329166, 'min_split_gain': 0.055617749187142795, 'subsample': 0.588293293566793, 'subsample_freq': 8, 'colsample_bytree': 0.9652110371773281, 'reg_alpha': 0.7573992940181531, 'reg_lambda': 0.7474292044884243, 'feature_fraction': 0.9559742828951712, 'bagging_fraction': 0.6771706825537044, 'lambda_l1': 4.139057761643566, 'lambda_l2': 1.6810677337501878}. Best is trial 47 with value: 0.5453298383847709.
# [I 2024-11-28 01:30:26,440] Trial 71 finished with value: 0.5443022578335167 and parameters: {'n_estimators': 1449, 'max_depth': 4, 'learning_rate': 0.007943208241601912, 'num_leaves': 44, 'max_bin': 406, 'min_child_samples': 63, 'min_child_weight': 4.904742136307203, 'min_split_gain': 0.3585078012151338, 'subsample': 0.6292489539298514, 'subsample_freq': 10, 'colsample_bytree': 0.8699183916801259, 'reg_alpha': 0.9609406918236327, 'reg_lambda': 0.6379980610510964, 'feature_fraction': 0.997481170772496, 'bagging_fraction': 0.7074373578987819, 'lambda_l1': 3.4019883988239887, 'lambda_l2': 1.8761424882258662}. Best is trial 47 with value: 0.5453298383847709.
# ...
# [I 2024-11-28 01:30:49,661] Trial 77 finished with value: 0.5428751787342383 and parameters: {'n_estimators': 1311, 'max_depth': 7, 'learning_rate': 0.017359934232156853, 'num_leaves': 38, 'max_bin': 203, 'min_child_samples': 60, 'min_child_weight': 5.1483069131589705, 'min_split_gain': 0.4440544808053333, 'subsample': 0.6639460937824406, 'subsample_freq': 10, 'colsample_bytree': 0.7884161827939615, 'reg_alpha': 0.9366173362420425, 'reg_lambda': 0.42390269990458673, 'feature_fraction': 0.870842940417422, 'bagging_fraction': 0.7198597448259887, 'lambda_l1': 3.14132873709226, 'lambda_l2': 3.6692614246349375}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:30:58,506] Trial 78 finished with value: 0.5438740778816632 and parameters: {'n_estimators': 1033, 'max_depth': 5, 'learning_rate': 0.004984981583977294, 'num_leaves': 20, 'max_bin': 377, 'min_child_samples': 70, 'min_child_weight': 5.526396685098723, 'min_split_gain': 0.4579922480802075, 'subsample': 0.5749103722227121, 'subsample_freq': 8, 'colsample_bytree': 0.8127540598300411, 'reg_alpha': 0.7202829428930498, 'reg_lambda': 0.5767747436821048, 'feature_fraction': 0.981716370534236, 'bagging_fraction': 0.7722771083700907, 'lambda_l1': 3.4252095429173735, 'lambda_l2': 2.2328017005906826}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:01,325] Trial 79 finished with value: 0.5406484180963199 and parameters: {'n_estimators': 1338, 'max_depth': 4, 'learning_rate': 0.022357266255982954, 'num_leaves': 62, 'max_bin': 443, 'min_child_samples': 76, 'min_child_weight': 4.632596820798559, 'min_split_gain': 0.388014645524242, 'subsample': 0.7487498402861562, 'subsample_freq': 9, 'colsample_bytree': 0.8380986737857157, 'reg_alpha': 0.7974594265023666, 'reg_lambda': 0.8461090677195526, 'feature_fraction': 0.897020244039096, 'bagging_fraction': 0.700815927305418, 'lambda_l1': 2.927917450324169, 'lambda_l2': 1.5100691948442848}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:03,735] Trial 80 finished with value: 0.538421987457508 and parameters: {'n_estimators': 1074, 'max_depth': 5, 'learning_rate': 0.0351057738254195, 'num_leaves': 74, 'max_bin': 402, 'min_child_samples': 66, 'min_child_weight': 3.4726726405927755, 'min_split_gain': 0.13559539661953604, 'subsample': 0.7008484861120361, 'subsample_freq': 10, 'colsample_bytree': 0.948422479984818, 'reg_alpha': 0.8782199303632948, 'reg_lambda': 0.8846439996463853, 'feature_fraction': 0.9358644200446709, 'bagging_fraction': 0.551573750450117, 'lambda_l1': 4.2016861794987115, 'lambda_l2': 4.793471078175209}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:08,899] Trial 81 finished with value: 0.5447875724454982 and parameters: {'n_estimators': 1151, 'max_depth': 4, 'learning_rate': 0.007804275427297154, 'num_leaves': 45, 'max_bin': 404, 'min_child_samples': 61, 'min_child_weight': 5.0261724531396865, 'min_split_gain': 0.3612512916045842, 'subsample': 0.6224666144749311, 'subsample_freq': 10, 'colsample_bytree': 0.8691412715175998, 'reg_alpha': 0.9669683328767262, 'reg_lambda': 0.6366606735953508, 'feature_fraction': 0.992555564654283, 'bagging_fraction': 0.7083526424278468, 'lambda_l1': 3.613782447977353, 'lambda_l2': 2.4157870908580668}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:14,095] Trial 82 finished with value: 0.5447589928932451 and parameters: {'n_estimators': 1164, 'max_depth': 4, 'learning_rate': 0.009314303297630023, 'num_leaves': 31, 'max_bin': 414, 'min_child_samples': 55, 'min_child_weight': 4.260967301455373, 'min_split_gain': 0.4047543153758379, 'subsample': 0.6165743021614946, 'subsample_freq': 10, 'colsample_bytree': 0.8591097432725099, 'reg_alpha': 0.973506627350008, 'reg_lambda': 0.6162943941177625, 'feature_fraction': 0.9862753578135128, 'bagging_fraction': 0.7548844363565392, 'lambda_l1': 3.6393273806858213, 'lambda_l2': 1.9551885673085727}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:19,661] Trial 83 finished with value: 0.54587224691625 and parameters: {'n_estimators': 1241, 'max_depth': 4, 'learning_rate': 0.009166125795208691, 'num_leaves': 32, 'max_bin': 390, 'min_child_samples': 52, 'min_child_weight': 4.33879011001471, 'min_split_gain': 0.4180490453877126, 'subsample': 0.621142225281169, 'subsample_freq': 10, 'colsample_bytree': 0.8413936661318848, 'reg_alpha': 0.970717207170803, 'reg_lambda': 0.5106194164631248, 'feature_fraction': 0.9872708870687519, 'bagging_fraction': 0.7529174856092419, 'lambda_l1': 3.606366261957812, 'lambda_l2': 1.97696649943017}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:24,605] Trial 84 finished with value: 0.5439027144707991 and parameters: {'n_estimators': 1144, 'max_depth': 4, 'learning_rate': 0.009200520982128972, 'num_leaves': 33, 'max_bin': 385, 'min_child_samples': 51, 'min_child_weight': 3.8463412025212564, 'min_split_gain': 0.3663322376524852, 'subsample': 0.6259307167275291, 'subsample_freq': 10, 'colsample_bytree': 0.846817237128262, 'reg_alpha': 0.9769133357111089, 'reg_lambda': 0.6085387130942885, 'feature_fraction': 0.9844794321771052, 'bagging_fraction': 0.7503436589640224, 'lambda_l1': 3.317593984005904, 'lambda_l2': 2.4201930673983596}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:29,446] Trial 85 finished with value: 0.5438742326960588 and parameters: {'n_estimators': 1235, 'max_depth': 5, 'learning_rate': 0.01142132195235497, 'num_leaves': 51, 'max_bin': 393, 'min_child_samples': 57, 'min_child_weight': 4.232823857442588, 'min_split_gain': 0.41084323247463894, 'subsample': 0.6052024071065271, 'subsample_freq': 10, 'colsample_bytree': 0.8638960815192972, 'reg_alpha': 0.9248809721992137, 'reg_lambda': 0.5148653654145423, 'feature_fraction': 0.9524061442337842, 'bagging_fraction': 0.737913876258021, 'lambda_l1': 3.518146431597468, 'lambda_l2': 1.9449667028362534}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:34,885] Trial 86 finished with value: 0.5427322606026574 and parameters: {'n_estimators': 1091, 'max_depth': 4, 'learning_rate': 0.00612447044900536, 'num_leaves': 251, 'max_bin': 355, 'min_child_samples': 55, 'min_child_weight': 2.9793070600438716, 'min_split_gain': 0.3329073503486765, 'subsample': 0.6465719799616014, 'subsample_freq': 10, 'colsample_bytree': 0.8821866309344065, 'reg_alpha': 0.9790749805749839, 'reg_lambda': 0.5542695494680778, 'feature_fraction': 0.9899956086010847, 'bagging_fraction': 0.6784029430933278, 'lambda_l1': 3.6365533950622453, 'lambda_l2': 2.6362538819490613}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:40,322] Trial 87 finished with value: 0.542075737565318 and parameters: {'n_estimators': 1194, 'max_depth': 6, 'learning_rate': 0.009484796493880862, 'num_leaves': 28, 'max_bin': 403, 'min_child_samples': 45, 'min_child_weight': 3.3091915938471987, 'min_split_gain': 0.2068524912117875, 'subsample': 0.6170964756963149, 'subsample_freq': 9, 'colsample_bytree': 0.8399154351457399, 'reg_alpha': 0.948118807524631, 'reg_lambda': 0.47644117987320733, 'feature_fraction': 0.9589348049707769, 'bagging_fraction': 0.6528630770985722, 'lambda_l1': 2.8418409324454434, 'lambda_l2': 2.8534787087735123}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:44,301] Trial 88 finished with value: 0.5431319465575818 and parameters: {'n_estimators': 1119, 'max_depth': 5, 'learning_rate': 0.014362351829031991, 'num_leaves': 173, 'max_bin': 425, 'min_child_samples': 52, 'min_child_weight': 7.7212458104184805, 'min_split_gain': 0.3036285452288549, 'subsample': 0.5659472323434934, 'subsample_freq': 9, 'colsample_bytree': 0.7698631302021646, 'reg_alpha': 0.969736164770847, 'reg_lambda': 0.629996547073364, 'feature_fraction': 0.9983551503426374, 'bagging_fraction': 0.7546636025144648, 'lambda_l1': 1.8552171066401586, 'lambda_l2': 1.766473568656749}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:48,859] Trial 89 finished with value: 0.5440167882360288 and parameters: {'n_estimators': 995, 'max_depth': 4, 'learning_rate': 0.010306985759256676, 'num_leaves': 37, 'max_bin': 379, 'min_child_samples': 67, 'min_child_weight': 5.091023752195521, 'min_split_gain': 0.4380993995805456, 'subsample': 0.5887406226943459, 'subsample_freq': 10, 'colsample_bytree': 0.8043249616181911, 'reg_alpha': 0.9984867995557657, 'reg_lambda': 0.43638918803452564, 'feature_fraction': 0.9765235186873719, 'bagging_fraction': 0.7733411145870274, 'lambda_l1': 3.8494379218554284, 'lambda_l2': 2.2922889937240787}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:31:58,719] Trial 90 finished with value: 0.5448446011799872 and parameters: {'n_estimators': 1235, 'max_depth': 5, 'learning_rate': 0.004748461952549447, 'num_leaves': 27, 'max_bin': 391, 'min_child_samples': 79, 'min_child_weight': 5.9258941900270505, 'min_split_gain': 0.3793119309582564, 'subsample': 0.6532453237364759, 'subsample_freq': 10, 'colsample_bytree': 0.8185107437919196, 'reg_alpha': 0.8467482430599079, 'reg_lambda': 0.5893638852113816, 'feature_fraction': 0.9406024711193264, 'bagging_fraction': 0.9768678715142893, 'lambda_l1': 3.1156841425598953, 'lambda_l2': 2.107787621398438}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:32:08,785] Trial 91 finished with value: 0.5437028735303683 and parameters: {'n_estimators': 1238, 'max_depth': 5, 'learning_rate': 0.004783566954128779, 'num_leaves': 29, 'max_bin': 391, 'min_child_samples': 78, 'min_child_weight': 4.6669502756863, 'min_split_gain': 0.3830329703205942, 'subsample': 0.6164719774107663, 'subsample_freq': 10, 'colsample_bytree': 0.8589758081443736, 'reg_alpha': 0.8400587798067589, 'reg_lambda': 0.5914998062544029, 'feature_fraction': 0.9361353148976396, 'bagging_fraction': 0.9653143857440303, 'lambda_l1': 3.648463163788166, 'lambda_l2': 2.067999135237576}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:32:27,207] Trial 92 finished with value: 0.5447589847451191 and parameters: {'n_estimators': 1159, 'max_depth': 17, 'learning_rate': 0.003241294851007069, 'num_leaves': 25, 'max_bin': 410, 'min_child_samples': 91, 'min_child_weight': 7.151123077154332, 'min_split_gain': 0.34822560303234973, 'subsample': 0.6278953134556027, 'subsample_freq': 10, 'colsample_bytree': 0.89847995851672, 'reg_alpha': 0.9117994584845943, 'reg_lambda': 0.4991366962663398, 'feature_fraction': 0.9204381683983385, 'bagging_fraction': 0.9350712807940693, 'lambda_l1': 3.1035318348200276, 'lambda_l2': 3.089458634639275}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:32:44,551] Trial 93 finished with value: 0.5426465830568435 and parameters: {'n_estimators': 1163, 'max_depth': 17, 'learning_rate': 0.0032837780130439745, 'num_leaves': 34, 'max_bin': 411, 'min_child_samples': 88, 'min_child_weight': 7.62278155357545, 'min_split_gain': 0.34309755633207056, 'subsample': 0.6712068452298727, 'subsample_freq': 9, 'colsample_bytree': 0.8194981140518515, 'reg_alpha': 0.9143968492750721, 'reg_lambda': 0.5026161464354091, 'feature_fraction': 0.9163156426546012, 'bagging_fraction': 0.947095394705059, 'lambda_l1': 3.089343633908303, 'lambda_l2': 3.1308264223070488}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:33:01,788] Trial 94 finished with value: 0.5436173426508242 and parameters: {'n_estimators': 1335, 'max_depth': 20, 'learning_rate': 0.004086512845733349, 'num_leaves': 45, 'max_bin': 396, 'min_child_samples': 92, 'min_child_weight': 6.988453196093667, 'min_split_gain': 0.4022357607402943, 'subsample': 0.6320969623274628, 'subsample_freq': 10, 'colsample_bytree': 0.9007018268768705, 'reg_alpha': 0.8713312914392527, 'reg_lambda': 0.49402916661017365, 'feature_fraction': 0.9537590045342574, 'bagging_fraction': 0.9772192907885602, 'lambda_l1': 2.715290174200026, 'lambda_l2': 2.1650791380473215}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:33:24,809] Trial 95 finished with value: 0.5421043334138232 and parameters: {'n_estimators': 1266, 'max_depth': 19, 'learning_rate': 0.0024034938252921302, 'num_leaves': 26, 'max_bin': 386, 'min_child_samples': 82, 'min_child_weight': 8.188517241175227, 'min_split_gain': 0.3784495059670606, 'subsample': 0.6569282949284778, 'subsample_freq': 9, 'colsample_bytree': 0.7858730347364548, 'reg_alpha': 0.7855369774471277, 'reg_lambda': 0.5383981805009947, 'feature_fraction': 0.9871798421035164, 'bagging_fraction': 0.9367992618626968, 'lambda_l1': 2.9624384018123378, 'lambda_l2': 2.4058650699583897}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:33:31,856] Trial 96 finished with value: 0.5427323746764227 and parameters: {'n_estimators': 823, 'max_depth': 14, 'learning_rate': 0.011957648886814155, 'num_leaves': 39, 'max_bin': 363, 'min_child_samples': 92, 'min_child_weight': 6.0647877481622725, 'min_split_gain': 0.4189020327977344, 'subsample': 0.6800395319311509, 'subsample_freq': 10, 'colsample_bytree': 0.8815710262876854, 'reg_alpha': 0.9306100697650034, 'reg_lambda': 0.4481260279632203, 'feature_fraction': 0.9425158994219509, 'bagging_fraction': 0.9738038654980439, 'lambda_l1': 3.283418991850875, 'lambda_l2': 3.4124409311246766}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:33:51,652] Trial 97 finished with value: 0.542646701204672 and parameters: {'n_estimators': 1199, 'max_depth': 17, 'learning_rate': 0.0034029675572479286, 'num_leaves': 31, 'max_bin': 437, 'min_child_samples': 72, 'min_child_weight': 6.647882114779749, 'min_split_gain': 0.3502650891196085, 'subsample': 0.6524401061845018, 'subsample_freq': 9, 'colsample_bytree': 0.9205132973934083, 'reg_alpha': 0.8972989743507939, 'reg_lambda': 0.6130321956093624, 'feature_fraction': 0.9622357607607923, 'bagging_fraction': 0.9987615795795602, 'lambda_l1': 2.5254370897689005, 'lambda_l2': 1.9728627845539062}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:34:01,943] Trial 98 finished with value: 0.5445877803938242 and parameters: {'n_estimators': 1294, 'max_depth': 6, 'learning_rate': 0.0061185903809562936, 'num_leaves': 25, 'max_bin': 422, 'min_child_samples': 100, 'min_child_weight': 7.093746815464085, 'min_split_gain': 0.3964218637798713, 'subsample': 0.5895019078519514, 'subsample_freq': 10, 'colsample_bytree': 0.8426277395112085, 'reg_alpha': 0.8361213837872964, 'reg_lambda': 0.5758085336316248, 'feature_fraction': 0.9245259024371791, 'bagging_fraction': 0.7303854374771106, 'lambda_l1': 3.176453773079018, 'lambda_l2': 1.7934946729512622}. Best is trial 72 with value: 0.5461005614832948.
# [I 2024-11-28 01:34:12,984] Trial 99 finished with value: 0.5418474189242103 and parameters: {'n_estimators': 1313, 'max_depth': 15, 'learning_rate': 0.00559006208717577, 'num_leaves': 41, 'max_bin': 375, 'min_child_samples': 99, 'min_child_weight': 6.915791291046564, 'min_split_gain': 0.39369603744843396, 'subsample': 0.596688364682916, 'subsample_freq': 10, 'colsample_bytree': 0.8285843878426571, 'reg_alpha': 0.812688173330474, 'reg_lambda': 0.5686700063251129, 'feature_fraction': 0.9244885048652451, 'bagging_fraction': 0.9152739383322315, 'lambda_l1': 3.1943956664146604, 'lambda_l2': 1.6520925918143279}. Best is trial 72 with value: 0.5461005614832948.
# Best parameters: {'n_estimators': 1304, 'max_depth': 4, 'learning_rate': 0.014480886301340897, 'num_leaves': 27, 'max_bin': 382, 'min_child_samples': 76, 'min_child_weight': 4.6682533046391255, 'min_split_gain': 0.38478034627797414, 'subsample': 0.6177299467577926, 'subsample_freq': 10, 'colsample_bytree': 0.834551325185271, 'reg_alpha': 0.9699400502628287, 'reg_lambda': 0.6925880649213346, 'feature_fraction': 0.9767949315943845, 'bagging_fraction': 0.6965092334514705, 'lambda_l1': 3.3468420383242075, 'lambda_l2': 2.275727393690836}
# Best score: 0.5461005614832948

# %%
# 最適なパラメータの取得
best_params = study.best_params

# 最適なパラメータを使用して再度モデルを訓練
best_model = lgb.LGBMClassifier(**best_params)
best_model.fit(X_train, y_train)
# Out:
# LGBMClassifier(bagging_fraction=0.6965092334514705,
#                colsample_bytree=0.834551325185271,
#                feature_fraction=0.9767949315943845,
#                lambda_l1=3.3468420383242075, lambda_l2=2.275727393690836,
#                learning_rate=0.014480886301340897, max_bin=382, max_depth=4,
#                min_child_samples=76, min_child_weight=4.6682533046391255,
#                min_split_gain=0.38478034627797414, n_estimators=1304,
#                num_leaves=27, reg_alpha=0.9699400502628287,
#                reg_lambda=0.6925880649213346, subsample=0.6177299467577926,
#                subsample_freq=10)

# %%
# 評価
y_pred = best_model.predict(X_test)
y_pred_proba = best_model.predict_proba(X_test)[:, 1]  # クラス1の確率
tune_accuracy = accuracy_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)  # 確率を使ってAUCを計算

print(f'Accuracy: {tune_accuracy:.4f}, ROC AUC: {roc_auc:.4f}')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5300, ROC AUC: 0.5482
#               precision    recall  f1-score   support
#
#            0       0.52      0.62      0.56      3898
#            1       0.55      0.44      0.49      4063
#
#     accuracy                           0.53      7961
#    macro avg       0.53      0.53      0.53      7961
# weighted avg       0.53      0.53      0.53      7961

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve')
plt.show()

# %%
lgb_model = lgb.LGBMClassifier(objective='binary', metric='binary_logloss', verbosity=-1)
scores = cross_val_score(lgb_model, X_train, y_train, cv=5, scoring='accuracy')
print("Cross-validated accuracy:", scores.mean())
# Out:
# Cross-validated accuracy: 0.5126170758404354

# %%
# バックテストの実行
# 取引シミュレーション
tune_capital = initial_capital  # 初期資金をリセット
capital_history = []
positions = []
buy_signals = []
sell_signals = []

for i in range(len(test_dates)-1):
    date = test_dates[i]
    prediction = y_pred[i]
    close_price = df.loc[date, 'close']
    next_date = test_dates[i+1]
    next_close_price = df.loc[next_date, 'close']
    
    # ポジションの決定
    if prediction == 1:
        position = 1  # ロング
        buy_signals.append((next_date, next_close_price))  # 買いのシグナル
    else:
        position = -1  # ショート
        sell_signals.append((next_date, next_close_price))  # 売りのシグナル
    
    # リターンの計算
    ret = (next_close_price - close_price) / close_price * position * leverage
    tune_capital = tune_capital * (1 + ret)
    capital_history.append(tune_capital)
    positions.append(position)

# バックテスト結果のデータフレーム作成
backtest_results = pd.DataFrame(index=test_dates[:-1])
backtest_results['tune_capital'] = capital_history
backtest_results['Position'] = positions

# リターンの計算
backtest_results['Return'] = backtest_results['tune_capital'].pct_change().fillna(0)

# シャープレシオの計算（リスクフリーレートは0と仮定）
tune_sharpe_ratio = (backtest_results['Return'].mean() / backtest_results['Return'].std()) * np.sqrt(365 * 24)

print('Final tune_capital:', tune_capital)
print('Sharpe Ratio:', tune_sharpe_ratio)

# 資産推移と売買のプロット
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

# 1つ目のグラフ: 資産推移のプロット
plt.subplot(2, 1, 1)  # 2行1列のグラフの1番目
plt.plot(backtest_results.index, backtest_results['tune_capital'], label='Capital Over Time')
plt.title('Capital Over Time')
plt.xlabel('Date')
plt.ylabel('tune_Capital')
plt.legend()

# 2つ目のグラフ: BTC価格と売買シグナルのプロット
plt.subplot(2, 1, 2)  # 2行1列のグラフの2番目
plt.plot(df.loc[test_dates[:-1], 'close'], label='BTC Price', color='blue')

# 買いのシグナル（緑の丸）
if buy_signals:
    buy_dates, buy_prices = zip(*buy_signals)
    plt.scatter(buy_dates, buy_prices, color='green', label='Buy Signal', marker='o')

# 売りのシグナル（赤の丸）
if sell_signals:
    sell_dates, sell_prices = zip(*sell_signals)
    plt.scatter(sell_dates, sell_prices, color='red', label='Sell Signal', marker='o')

plt.title('BTC Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('BTC Price')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final tune_capital: 3141906.6043627304
# Sharpe Ratio: 1.7318554272321804

# %%
# リターン分布のプロット
plt.figure(figsize=(12,6))
sns.histplot(backtest_results['Return'], bins=50, kde=True)
plt.title('Returns Distribution (Optimized Model)')
plt.show()

# %%
backtest_results['Return']
# Out:
# timestamp
# 2024-01-01 00:00:00    0.000000
# 2024-01-01 01:00:00    0.001523
# 2024-01-01 02:00:00    0.011771
# 2024-01-01 03:00:00    0.003284
# 2024-01-01 04:00:00    0.007829
#                          ...
# 2024-11-27 11:00:00   -0.002828
# 2024-11-27 12:00:00   -0.016342
# 2024-11-27 13:00:00   -0.012081
# 2024-11-27 14:00:00   -0.015239
# 2024-11-27 15:00:00    0.001506
# Name: Return, Length: 7960, dtype: float64

# %%
# 最適化されたモデルの保存
joblib.dump(best_model, 'lightgbm_btc_model_optimized.pkl')

print("モデルを保存しました: lightgbm_btc_model_optimized.pkl")
# Out:
# モデルを保存しました: lightgbm_btc_model_optimized.pkl

# %%
# 特徴量の重要度をプロット
lgb.plot_importance(best_model, max_num_features=1000)
plt.show()

# %%
# 保存するデータ
timeframe = '1h' 
data = {'時間足':[timeframe], 'レバレッジ':[leverage], '特徴量' : [features], 'テスト開始時期' : [split_date], '精度' : [accuracy], 
        '最終資産' : [capital], 'シャープレシオ' : [sharpe_ratio], 'チューン後精度' : [tune_accuracy], 
        'チューン後最終資産' : [tune_capital], 'チューン後シャープレシオ' : [tune_sharpe_ratio]}

df_result = pd.DataFrame(data)

# 'result.csv'が既に存在するか確認
file_exists = os.path.isfile('result.csv')

# CSVファイルに追記、ファイルが既に存在する場合はヘッダーを追加しない
df_result.to_csv('result.csv', mode='a', header=not file_exists, index=False)

# %%
print('Final capital:', capital)
print('Final tune_capital:', tune_capital)
# Out:
# Final capital: 3086832.6201648456
# Final tune_capital: 3141906.6043627304

# %%
# 予測結果をCSVファイルに保存
np.savetxt("lgb_tuned_pred.csv", y_pred, delimiter=",")

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_test
# Out:
# timestamp
# 2024-01-01 00:00:00    1
# 2024-01-01 01:00:00    0
# 2024-01-01 02:00:00    0
# 2024-01-01 03:00:00    1
# 2024-01-01 04:00:00    0
#                       ..
# 2024-11-27 12:00:00    1
# 2024-11-27 13:00:00    1
# 2024-11-27 14:00:00    1
# 2024-11-27 15:00:00    0
# 2024-11-27 16:00:00    0
# Name: target, Length: 7961, dtype: int64
