# %%
# 必要なライブラリのインポート
import numpy as np
import pandas as pd
import xgboost as xgb
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
import ccxt
from datetime import datetime, timedelta
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
import warnings
import os
import sweetviz as sv
from IPython.display import IFrame
import time
import requests
from sklearn.model_selection import cross_val_score
warnings.filterwarnings('ignore')

# %%
# データの読み込みと文字列として保存されている日時情報を日時型のデータに変換
df = pd.read_csv('btc_usdt_1h_2018_to_now.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
# タイムスタンプでソートとインデックスのリセット
df.sort_values('timestamp', inplace=True)#inplaceで新しいdataframeを作成せず元のを変更
# 列をインデックス（行ラベル）として設定
df.set_index('timestamp', inplace=True)

# %%
df['close'].plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
# 特徴量エンジニアリング
# 移動平均線の計算
df['SMA_10'] = df['close'].rolling(window=10).mean()
df['SMA_20'] = df['close'].rolling(window=20).mean()
df['SMA_30'] = df['close'].rolling(window=30).mean()
df['SMA_100'] = df['close'].rolling(window=100).mean()
df['SMA_200'] = df['close'].rolling(window=200).mean()

# 指数移動平均線の計算
df['EMA_20'] = df['close'].ewm(span=20, adjust=False).mean()
df['EMA_200'] = df['close'].ewm(span=200, adjust=False).mean()

# RSIの計算
def compute_RSI(data, time_window):
    diff = data.diff(1) #1つ前の行との違い
    up_chg = diff.clip(lower=0) #差分が負の物は0に変換
    down_chg = -diff.clip(upper=0) #差分が0より大きいものを全て0に置き換える
    up_chg_avg = up_chg.ewm(com=time_window - 1, min_periods=time_window).mean() #価格が上昇した指数移動平均
    down_chg_avg = down_chg.ewm(com=time_window - 1, min_periods=time_window).mean()
    rs = up_chg_avg / down_chg_avg #上昇した強さと下落した強さの比率
    rsi = 100 - 100 / (1 + rs) 
    return rsi

df['RSI_14'] = compute_RSI(df['close'], 14)

# MACDの計算
df['EMA_12'] = df['close'].ewm(span=12, adjust=False).mean()
df['EMA_26'] = df['close'].ewm(span=26, adjust=False).mean()
df['MACD'] = df['EMA_12'] - df['EMA_26']
df['Signal_Line'] = df['MACD'].ewm(span=9, adjust=False).mean()

# ボリンジャーバンドの計算
df['STD_20'] = df['close'].rolling(window=20).std() #stdは標準偏差(データのばらつき度合い)を計算
df['Upper_Band'] = df['SMA_20'] + (df['STD_20'] * 2)
df['Lower_Band'] = df['SMA_20'] - (df['STD_20'] * 2)

# 遅延特徴量の作成
for lag in range(1, 6): #shift(lag) は、df['close'] のデータを lag 分だけ下にシフト
    df[f'lag_{lag}'] = df['close'].shift(lag) #lag_1からlag_5 までの5つの遅延列が作成

# 時間に関する特徴量
df['hour'] = df.index.hour
df['day_of_week'] = df.index.dayofweek #曜日は0から6の値で表される

#ATR（平均真の範囲、Average True Range）
df['TR'] = df['high'] - df['low']
df['ATR_14'] = df['TR'].rolling(window=14).mean()

#ADX（平均方向性指数、Average Directional Index）
def compute_ADX(data, period=14):
    high = data['high']
    low = data['low']
    close = data['close']
    
    plus_dm = high.diff()
    minus_dm = low.diff()

    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0

    tr = high.combine(low, max) - low.combine(close.shift(), min)

    atr = tr.rolling(window=period).mean()

    plus_di = 100 * (plus_dm.ewm(alpha=1/period).mean() / atr)
    minus_di = abs(100 * (minus_dm.ewm(alpha=1/period).mean() / atr))
    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100
    adx = dx.rolling(window=period).mean()
    
    return adx

df['ADX_14'] = compute_ADX(df)

#CCI（商品チャンネル指数、Commodity Channel Index）
df['TP'] = (df['high'] + df['low'] + df['close']) / 3
df['CCI_14'] = (df['TP'] - df['TP'].rolling(window=14).mean()) / (0.015 * df['TP'].rolling(window=14).std())

#OBV（オンバランスボリューム、On-Balance Volume）
df['OBV'] = (np.sign(df['close'].diff()) * df['volume']).fillna(0).cumsum()

#Stochastic Oscillator（ストキャスティクス）
df['L14'] = df['low'].rolling(window=14).min()
df['H14'] = df['high'].rolling(window=14).max()
df['%K'] = 100 * (df['close'] - df['L14']) / (df['H14'] - df['L14'])
df['%D'] = df['%K'].rolling(window=3).mean()

df['Volatility'] = df['close'].rolling(window=10).std()
df['Volume_Change'] = df['volume'].pct_change()

# %%
# 目標変数の作成
df['return'] = df['close'].pct_change().shift(0) #前の行とのパーセンテージの変化
df['target'] = (df['return'] > 0).astype(int) #価格が上昇したらTrue

# %%
# 欠損値の削除
df.dropna(inplace=True)

# %%
# 特徴量と目標変数の定義
features = ['open', 'high', 'low', 'close', 'volume', 'SMA_10', 'SMA_30','SMA_100', 'SMA_200',
            'EMA_20',  'EMA_200', 'RSI_14', 'MACD', 'Signal_Line',
            'Upper_Band', 'Lower_Band', 'ATR_14', 'ADX_14', 'CCI_14', 'OBV', '%K', '%D', 'hour', 'day_of_week', 'Volatility', 'Volume_Change'] + [f'lag_{lag}' for lag in range(1,6)]

X = df[features]
y = df['target'] #価格が上昇すれば1下落すれば0

# %%
# データの分割（時間ベースでの分割）
split_date = '2024-01-01'
X_train = X[X.index < split_date]
X_test = X[X.index >= split_date]
y_train = y[y.index < split_date]
y_test = y[y.index >= split_date]

# %%
print("X_train columns:", X_train.columns)
print("X_test columns:", X_test.columns)
# Out:
# X_train columns: Index(['open', 'high', 'low', 'close', 'volume', 'SMA_10', 'SMA_30', 'SMA_100',
#        'SMA_200', 'EMA_20', 'EMA_200', 'RSI_14', 'MACD', 'Signal_Line',
#        'Upper_Band', 'Lower_Band', 'ATR_14', 'ADX_14', 'CCI_14', 'OBV', '%K',
#        '%D', 'hour', 'day_of_week', 'Volatility', 'Volume_Change', 'lag_1',
#        'lag_2', 'lag_3', 'lag_4', 'lag_5'],
#       dtype='object')
# X_test columns: Index(['open', 'high', 'low', 'close', 'volume', 'SMA_10', 'SMA_30', 'SMA_100',
#        'SMA_200', 'EMA_20', 'EMA_200', 'RSI_14', 'MACD', 'Signal_Line',
#        'Upper_Band', 'Lower_Band', 'ATR_14', 'ADX_14', 'CCI_14', 'OBV', '%K',
#        '%D', 'hour', 'day_of_week', 'Volatility', 'Volume_Change', 'lag_1',
#        'lag_2', 'lag_3', 'lag_4', 'lag_5'],
#       dtype='object')

# %%
# 各列で無限大をNaNに変換
X_train.replace([np.inf, -np.inf], np.nan, inplace=True)

# 各列のNaNを、その列の平均値で置き換える
X_train = X_train.apply(lambda x: x.fillna(x.mean()), axis=0)

# 同様に、X_testにも適用
X_test.replace([np.inf, -np.inf], np.nan, inplace=True)
X_test = X_test.apply(lambda x: x.fillna(x.mean()), axis=0)

# %%
print("X_train columns:", X_train.columns)
print("X_test columns:", X_test.columns)
# Out:
# X_train columns: Index(['open', 'high', 'low', 'close', 'volume', 'SMA_10', 'SMA_30', 'SMA_100',
#        'SMA_200', 'EMA_20', 'EMA_200', 'RSI_14', 'MACD', 'Signal_Line',
#        'Upper_Band', 'Lower_Band', 'ATR_14', 'ADX_14', 'CCI_14', 'OBV', '%K',
#        '%D', 'hour', 'day_of_week', 'Volatility', 'Volume_Change', 'lag_1',
#        'lag_2', 'lag_3', 'lag_4', 'lag_5'],
#       dtype='object')
# X_test columns: Index(['open', 'high', 'low', 'close', 'volume', 'SMA_10', 'SMA_30', 'SMA_100',
#        'SMA_200', 'EMA_20', 'EMA_200', 'RSI_14', 'MACD', 'Signal_Line',
#        'Upper_Band', 'Lower_Band', 'ATR_14', 'ADX_14', 'CCI_14', 'OBV', '%K',
#        '%D', 'hour', 'day_of_week', 'Volatility', 'Volume_Change', 'lag_1',
#        'lag_2', 'lag_3', 'lag_4', 'lag_5'],
#       dtype='object')

# %%
# XGBoostの分類モデルをインスタンス化
model = xgb.XGBClassifier(
    objective='binary:logistic',
    n_estimators=100,
    learning_rate=0.1,
    max_depth=5,
    random_state=42,
    use_label_encoder=False
)

# モデルの学習
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
# 予測
y_pred = model.predict(X_test)

# y_testと同じインデックスをy_predに設定
y_pred = pd.Series(y_pred, index=y_test.index)

# 精度と評価指標の表示
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8367274026438014
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83      4106
#            1       0.84      0.85      0.84      4291
#
#     accuracy                           0.84      8397
#    macro avg       0.84      0.84      0.84      8397
# weighted avg       0.84      0.84      0.84      8397

# %%
np.savetxt("xgb_pred.csv", y_pred, delimiter=",")

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# 初期設定
initial_capital = 1000000
capital = initial_capital  # 初期資金をリセット
capital_history = []
positions = []
buy_signals = []
sell_signals = []

leverage = 2  # レバレッジ

# 現在のポジションの状態を示す変数
current_position = 0  # 1=ロング, -1=ショート, 0=ポジションなし

# テスト期間の日付リスト
test_dates = X_test.index

for i in range(len(test_dates) - 1):
    date = test_dates[i]
    prediction = y_pred[i]
    close_price = df.loc[date, 'close']
    next_date = test_dates[i + 1]
    next_close_price = df.loc[next_date, 'close']
    
    # ポジションの決定と変更
    if prediction == 1:  # 上がると予想
        if current_position == -1:  # 現在ショートなら決済してロングに変更
            sell_signals.append((date, close_price))  # ショート決済
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        elif current_position == 0:
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        else:
            current_position = 1
        

    elif prediction == 0:  # 下がると予想
        if current_position == 1:  # 現在ロングなら決済してショートに変更
            buy_signals.append((date, close_price))  # ロング決済
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        elif current_position == 0:
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        else:
            current_position = -1

    # リターンの計算
    ret = (next_close_price - close_price) / close_price * current_position * leverage
    capital = capital * (1 + ret)
    capital_history.append(capital)
    positions.append(current_position)

# バックテスト結果のデータフレーム作成
backtest_results = pd.DataFrame(index=test_dates[:-1])
backtest_results['Capital'] = capital_history
backtest_results['Position'] = positions

# リターンの計算
backtest_results['Return'] = backtest_results['Capital'].pct_change().fillna(0)

# シャープレシオの計算（リスクフリーレートは0と仮定）
sharpe_ratio = (backtest_results['Return'].mean() / backtest_results['Return'].std()) * np.sqrt(365 * 24)

print('Final capital:', capital)
print('Sharpe Ratio:', sharpe_ratio)

# 資産推移と売買のプロット
plt.figure(figsize=(12, 12))

# 1つ目のグラフ: 資産推移のプロット
plt.subplot(2, 1, 1)
plt.plot(backtest_results.index, backtest_results['Capital'], label='Capital Over Time')
plt.title('Capital Over Time')
plt.xlabel('Date')
plt.ylabel('Capital')
plt.legend()

# 2つ目のグラフ: BTC価格と売買シグナルのプロット
plt.subplot(2, 1, 2)
plt.plot(df.loc[test_dates[:-1], 'close'], label='BTC Price', color='blue')

# 買いのシグナル（緑の丸）
if buy_signals:
    buy_dates, buy_prices = zip(*buy_signals)
    plt.scatter(buy_dates, buy_prices, color='green', label='Buy Signal', marker='o')

# 売りのシグナル（赤の丸）
if sell_signals:
    sell_dates, sell_prices = zip(*sell_signals)
    plt.scatter(sell_dates, sell_prices, color='red', label='Sell Signal', marker='o')

plt.title('BTC Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('BTC Price')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final capital: 60368.24715181686
# Sharpe Ratio: -2.2752783055768395

# %% [markdown]
# # ハイパーパラメータチューニング

# %%
param_grid = {
    'max_depth': [3, 5, 7],           # ツリーの深さ（深くしすぎると過学習のリスク）
    'learning_rate': [0.01, 0.1, 0.2],# 学習率（小さくすると学習は遅いが精度が安定しやすい）
    'n_estimators': [50, 100, 200],    # ツリーの数（多いほどモデルが複雑に）
    'subsample': [0.7, 0.8, 1.0],     # 各ツリーのサンプル使用割合
    'colsample_bytree': [0.7, 0.8, 1.0] # 各ツリーの特徴量使用割合
}

grid_search = GridSearchCV(
    estimator=xgb.XGBClassifier(objective='binary:logistic'),
    param_grid=param_grid,
    scoring='accuracy',
    cv=3,
    n_jobs=-1
)

# グリッドサーチで最適なパラメータを探索
grid_search.fit(X_train, y_train)

# 最適なパラメータでモデルを再作成
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8}

# %%
model = xgb.XGBClassifier(**best_params)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# 予測
y_pred = model.predict(X_test)

# y_testと同じインデックスをy_predに設定
y_pred = pd.Series(y_pred, index=y_test.index)

# 精度と評価指標の表示
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8368464927950459
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      4106
#            1       0.84      0.84      0.84      4291
#
#     accuracy                           0.84      8397
#    macro avg       0.84      0.84      0.84      8397
# weighted avg       0.84      0.84      0.84      8397

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
eval_set = [(X_train, y_train), (X_test, y_test)]
model = xgb.XGBClassifier(**best_params, early_stopping_rounds=10)
model.fit(X_train, y_train,  eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-logloss:0.66539	validation_1-logloss:0.66437
# [1]	validation_0-logloss:0.64191	validation_1-logloss:0.63906
# [2]	validation_0-logloss:0.61993	validation_1-logloss:0.61641
# [3]	validation_0-logloss:0.60066	validation_1-logloss:0.59617
# [4]	validation_0-logloss:0.58231	validation_1-logloss:0.57740
# [5]	validation_0-logloss:0.56611	validation_1-logloss:0.56165
# [6]	validation_0-logloss:0.55001	validation_1-logloss:0.54543
# [7]	validation_0-logloss:0.53630	validation_1-logloss:0.53158
# [8]	validation_0-logloss:0.52148	validation_1-logloss:0.51722
# [9]	validation_0-logloss:0.51065	validation_1-logloss:0.50666
# [10]	validation_0-logloss:0.49980	validation_1-logloss:0.49622
# [11]	validation_0-logloss:0.48935	validation_1-logloss:0.48613
# [12]	validation_0-logloss:0.48178	validation_1-logloss:0.47863
# [13]	validation_0-logloss:0.47312	validation_1-logloss:0.47051
# [14]	validation_0-logloss:0.46664	validation_1-logloss:0.46441
# [15]	validation_0-logloss:0.46057	validation_1-logloss:0.45882
# [16]	validation_0-logloss:0.45570	validation_1-logloss:0.45425
# [17]	validation_0-logloss:0.45037	validation_1-logloss:0.44947
# [18]	validation_0-logloss:0.44469	validation_1-logloss:0.44422
# [19]	validation_0-logloss:0.44096	validation_1-logloss:0.44083
# [20]	validation_0-logloss:0.43642	validation_1-logloss:0.43687
# [21]	validation_0-logloss:0.43230	validation_1-logloss:0.43293
# [22]	validation_0-logloss:0.42957	validation_1-logloss:0.43023
# [23]	validation_0-logloss:0.42606	validation_1-logloss:0.42711
# [24]	validation_0-logloss:0.42330	validation_1-logloss:0.42489
# [25]	validation_0-logloss:0.42041	validation_1-logloss:0.42227
# [26]	validation_0-logloss:0.41841	validation_1-logloss:0.42035
# [27]	validation_0-logloss:0.41492	validation_1-logloss:0.41732
# [28]	validation_0-logloss:0.41226	validation_1-logloss:0.41483
# [29]	validation_0-logloss:0.40895	validation_1-logloss:0.41223
# [30]	validation_0-logloss:0.40657	validation_1-logloss:0.41016
# [31]	validation_0-logloss:0.40493	validation_1-logloss:0.40898
# [32]	validation_0-logloss:0.40369	validation_1-logloss:0.40774
# [33]	validation_0-logloss:0.40092	validation_1-logloss:0.40531
# [34]	validation_0-logloss:0.39924	validation_1-logloss:0.40372
# [35]	validation_0-logloss:0.39670	validation_1-logloss:0.40151
# [36]	validation_0-logloss:0.39406	validation_1-logloss:0.39950
# [37]	validation_0-logloss:0.39266	validation_1-logloss:0.39828
# [38]	validation_0-logloss:0.39047	validation_1-logloss:0.39659
# [39]	validation_0-logloss:0.38851	validation_1-logloss:0.39501
# [40]	validation_0-logloss:0.38749	validation_1-logloss:0.39405
# [41]	validation_0-logloss:0.38533	validation_1-logloss:0.39221
# [42]	validation_0-logloss:0.38345	validation_1-logloss:0.39101
# [43]	validation_0-logloss:0.38262	validation_1-logloss:0.39010
# [44]	validation_0-logloss:0.38189	validation_1-logloss:0.38956
# [45]	validation_0-logloss:0.38062	validation_1-logloss:0.38860
# [46]	validation_0-logloss:0.37931	validation_1-logloss:0.38759
# [47]	validation_0-logloss:0.37796	validation_1-logloss:0.38683
# [48]	validation_0-logloss:0.37659	validation_1-logloss:0.38579
# [49]	validation_0-logloss:0.37545	validation_1-logloss:0.38492
# [50]	validation_0-logloss:0.37470	validation_1-logloss:0.38418
# [51]	validation_0-logloss:0.37363	validation_1-logloss:0.38335
# [52]	validation_0-logloss:0.37259	validation_1-logloss:0.38240
# [53]	validation_0-logloss:0.37128	validation_1-logloss:0.38138
# [54]	validation_0-logloss:0.37065	validation_1-logloss:0.38104
# [55]	validation_0-logloss:0.36920	validation_1-logloss:0.37993
# [56]	validation_0-logloss:0.36804	validation_1-logloss:0.37943
# [57]	validation_0-logloss:0.36753	validation_1-logloss:0.37908
# [58]	validation_0-logloss:0.36663	validation_1-logloss:0.37854
# [59]	validation_0-logloss:0.36602	validation_1-logloss:0.37827
# [60]	validation_0-logloss:0.36472	validation_1-logloss:0.37740
# [61]	validation_0-logloss:0.36343	validation_1-logloss:0.37664
# [62]	validation_0-logloss:0.36255	validation_1-logloss:0.37613
# [63]	validation_0-logloss:0.36145	validation_1-logloss:0.37542
# [64]	validation_0-logloss:0.36073	validation_1-logloss:0.37481
# [65]	validation_0-logloss:0.36018	validation_1-logloss:0.37431
# [66]	validation_0-logloss:0.35942	validation_1-logloss:0.37358
# [67]	validation_0-logloss:0.35826	validation_1-logloss:0.37272
# [68]	validation_0-logloss:0.35746	validation_1-logloss:0.37234
# [69]	validation_0-logloss:0.35705	validation_1-logloss:0.37197
# [70]	validation_0-logloss:0.35605	validation_1-logloss:0.37135
# [71]	validation_0-logloss:0.35566	validation_1-logloss:0.37107
# [72]	validation_0-logloss:0.35452	validation_1-logloss:0.37022
# [73]	validation_0-logloss:0.35402	validation_1-logloss:0.36968
# [74]	validation_0-logloss:0.35320	validation_1-logloss:0.36917
# [75]	validation_0-logloss:0.35206	validation_1-logloss:0.36855
# [76]	validation_0-logloss:0.35134	validation_1-logloss:0.36814
# [77]	validation_0-logloss:0.35057	validation_1-logloss:0.36765
# [78]	validation_0-logloss:0.34965	validation_1-logloss:0.36712
# [79]	validation_0-logloss:0.34909	validation_1-logloss:0.36671
# [80]	validation_0-logloss:0.34854	validation_1-logloss:0.36638
# [81]	validation_0-logloss:0.34757	validation_1-logloss:0.36587
# [82]	validation_0-logloss:0.34672	validation_1-logloss:0.36526
# [83]	validation_0-logloss:0.34641	validation_1-logloss:0.36510
# [84]	validation_0-logloss:0.34575	validation_1-logloss:0.36478
# [85]	validation_0-logloss:0.34530	validation_1-logloss:0.36471
# [86]	validation_0-logloss:0.34461	validation_1-logloss:0.36422
# [87]	validation_0-logloss:0.34409	validation_1-logloss:0.36394
# [88]	validation_0-logloss:0.34360	validation_1-logloss:0.36366
# [89]	validation_0-logloss:0.34287	validation_1-logloss:0.36356
# [90]	validation_0-logloss:0.34232	validation_1-logloss:0.36335
# [91]	validation_0-logloss:0.34187	validation_1-logloss:0.36305
# [92]	validation_0-logloss:0.34134	validation_1-logloss:0.36265
# [93]	validation_0-logloss:0.34078	validation_1-logloss:0.36263
# [94]	validation_0-logloss:0.34042	validation_1-logloss:0.36265
# [95]	validation_0-logloss:0.33976	validation_1-logloss:0.36219
# [96]	validation_0-logloss:0.33907	validation_1-logloss:0.36192
# [97]	validation_0-logloss:0.33834	validation_1-logloss:0.36156
# [98]	validation_0-logloss:0.33793	validation_1-logloss:0.36155
# [99]	validation_0-logloss:0.33739	validation_1-logloss:0.36132
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# 予測
y_pred = model.predict(X_test)

# y_testと同じインデックスをy_predに設定
y_pred = pd.Series(y_pred, index=y_test.index)

# 精度と評価指標の表示
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Accuracy: 0.8368464927950459
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      4106
#            1       0.84      0.84      0.84      4291
#
#     accuracy                           0.84      8397
#    macro avg       0.84      0.84      0.84      8397
# weighted avg       0.84      0.84      0.84      8397

# %%
# 初期設定
initial_capital = 1000000
capital = initial_capital  # 初期資金をリセット
capital_history = []
positions = []
buy_signals = []
sell_signals = []

leverage = 2  # レバレッジ

# 現在のポジションの状態を示す変数
current_position = 0  # 1=ロング, -1=ショート, 0=ポジションなし

# テスト期間の日付リスト
test_dates = X_test.index

for i in range(len(test_dates) - 1):
    date = test_dates[i]
    prediction = y_pred[i]
    close_price = df.loc[date, 'close']
    next_date = test_dates[i + 1]
    next_close_price = df.loc[next_date, 'close']
    
    # ポジションの決定と変更
    if prediction == 1:  # 上がると予想
        if current_position == -1:  # 現在ショートなら決済してロングに変更
            sell_signals.append((date, close_price))  # ショート決済
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        elif current_position == 0:
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        else:
            current_position = 1
        

    elif prediction == 0:  # 下がると予想
        if current_position == 1:  # 現在ロングなら決済してショートに変更
            buy_signals.append((date, close_price))  # ロング決済
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        elif current_position == 0:
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        else:
            current_position = -1

    # リターンの計算
    ret = (next_close_price - close_price) / close_price * current_position * leverage
    capital = capital * (1 + ret)
    capital_history.append(capital)
    positions.append(current_position)

# バックテスト結果のデータフレーム作成
backtest_results = pd.DataFrame(index=test_dates[:-1])
backtest_results['Capital'] = capital_history
backtest_results['Position'] = positions

# リターンの計算
backtest_results['Return'] = backtest_results['Capital'].pct_change().fillna(0)

# シャープレシオの計算（リスクフリーレートは0と仮定）
sharpe_ratio = (backtest_results['Return'].mean() / backtest_results['Return'].std()) * np.sqrt(365 * 24)

print('Final capital:', capital)
print('Sharpe Ratio:', sharpe_ratio)

# 資産推移と売買のプロット
plt.figure(figsize=(12, 12))

# 1つ目のグラフ: 資産推移のプロット
plt.subplot(2, 1, 1)
plt.plot(backtest_results.index, backtest_results['Capital'], label='Capital Over Time')
plt.title('Capital Over Time')
plt.xlabel('Date')
plt.ylabel('Capital')
plt.legend()

# 2つ目のグラフ: BTC価格と売買シグナルのプロット
plt.subplot(2, 1, 2)
plt.plot(df.loc[test_dates[:-1], 'close'], label='BTC Price', color='blue')

# 買いのシグナル（緑の丸）
if buy_signals:
    buy_dates, buy_prices = zip(*buy_signals)
    plt.scatter(buy_dates, buy_prices, color='green', label='Buy Signal', marker='o')

# 売りのシグナル（赤の丸）
if sell_signals:
    sell_dates, sell_prices = zip(*sell_signals)
    plt.scatter(sell_dates, sell_prices, color='red', label='Sell Signal', marker='o')

plt.title('BTC Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('BTC Price')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final capital: 47881.32982015252
# Sharpe Ratio: -2.5059483334046266

# %%
# 予測結果をCSVファイルに保存
np.savetxt("xgb_tuned_pred.csv", y_pred, delimiter=",")
