# %%
# 必要なライブラリのインポート
import numpy as np
import pandas as pd
import xgboost as xgb
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
import ccxt
from datetime import datetime, timedelta
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
import warnings
import os
import sweetviz as sv
from IPython.display import IFrame
import time
import requests
from sklearn.model_selection import cross_val_score
warnings.filterwarnings('ignore')

# %%
# データの読み込みと文字列として保存されている日時情報を日時型のデータに変換
df = pd.read_csv('btc_usdt_1h_2018_to_now.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
# タイムスタンプでソートとインデックスのリセット
df.sort_values('timestamp', inplace=True)#inplaceで新しいdataframeを作成せず元のを変更
# 列をインデックス（行ラベル）として設定
df.set_index('timestamp', inplace=True)

# %%
df['close'].plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
# 特徴量エンジニアリング
# 移動平均線の計算
df['SMA_10'] = df['close'].rolling(window=10).mean()
df['SMA_20'] = df['close'].rolling(window=20).mean()
df['SMA_30'] = df['close'].rolling(window=30).mean()
df['SMA_100'] = df['close'].rolling(window=100).mean()
df['SMA_200'] = df['close'].rolling(window=200).mean()

# 指数移動平均線の計算
df['EMA_20'] = df['close'].ewm(span=20, adjust=False).mean()
df['EMA_200'] = df['close'].ewm(span=200, adjust=False).mean()

# RSIの計算
def compute_RSI(data, time_window):
    diff = data.diff(1) #1つ前の行との違い
    up_chg = diff.clip(lower=0) #差分が負の物は0に変換
    down_chg = -diff.clip(upper=0) #差分が0より大きいものを全て0に置き換える
    up_chg_avg = up_chg.ewm(com=time_window - 1, min_periods=time_window).mean() #価格が上昇した指数移動平均
    down_chg_avg = down_chg.ewm(com=time_window - 1, min_periods=time_window).mean()
    rs = up_chg_avg / down_chg_avg #上昇した強さと下落した強さの比率
    rsi = 100 - 100 / (1 + rs) 
    return rsi

df['RSI_14'] = compute_RSI(df['close'], 14)

# MACDの計算
df['EMA_12'] = df['close'].ewm(span=12, adjust=False).mean()
df['EMA_26'] = df['close'].ewm(span=26, adjust=False).mean()
df['MACD'] = df['EMA_12'] - df['EMA_26']
df['Signal_Line'] = df['MACD'].ewm(span=9, adjust=False).mean()

# ボリンジャーバンドの計算
df['STD_20'] = df['close'].rolling(window=20).std() #stdは標準偏差(データのばらつき度合い)を計算
df['Upper_Band'] = df['SMA_20'] + (df['STD_20'] * 2)
df['Lower_Band'] = df['SMA_20'] - (df['STD_20'] * 2)

# 遅延特徴量の作成
for lag in range(1, 6): #shift(lag) は、df['close'] のデータを lag 分だけ下にシフト
    df[f'lag_{lag}'] = df['close'].shift(lag) #lag_1からlag_5 までの5つの遅延列が作成

# 時間に関する特徴量
df['hour'] = df.index.hour
df['day_of_week'] = df.index.dayofweek #曜日は0から6の値で表される

#ATR（平均真の範囲、Average True Range）
df['TR'] = df['high'] - df['low']
df['ATR_14'] = df['TR'].rolling(window=14).mean()

#ADX（平均方向性指数、Average Directional Index）
def compute_ADX(data, period=14):
    high = data['high']
    low = data['low']
    close = data['close']
    
    plus_dm = high.diff()
    minus_dm = low.diff()

    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0

    tr = high.combine(low, max) - low.combine(close.shift(), min)

    atr = tr.rolling(window=period).mean()

    plus_di = 100 * (plus_dm.ewm(alpha=1/period).mean() / atr)
    minus_di = abs(100 * (minus_dm.ewm(alpha=1/period).mean() / atr))
    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100
    adx = dx.rolling(window=period).mean()
    
    return adx

df['ADX_14'] = compute_ADX(df)

#CCI（商品チャンネル指数、Commodity Channel Index）
df['TP'] = (df['high'] + df['low'] + df['close']) / 3
df['CCI_14'] = (df['TP'] - df['TP'].rolling(window=14).mean()) / (0.015 * df['TP'].rolling(window=14).std())

#OBV（オンバランスボリューム、On-Balance Volume）
df['OBV'] = (np.sign(df['close'].diff()) * df['volume']).fillna(0).cumsum()

#Stochastic Oscillator（ストキャスティクス）
df['L14'] = df['low'].rolling(window=14).min()
df['H14'] = df['high'].rolling(window=14).max()
df['%K'] = 100 * (df['close'] - df['L14']) / (df['H14'] - df['L14'])
df['%D'] = df['%K'].rolling(window=3).mean()

# %%
# 目標変数の作成
df['return'] = df['close'].pct_change().shift(0) #前の行とのパーセンテージの変化
df['target'] = (df['return'] > 0).astype(int) #価格が上昇したらTrue

# %%
# 欠損値の削除
df.dropna(inplace=True)

# %%
# 特徴量と目標変数の定義
features = ['open', 'high', 'low', 'close', 'volume', 'SMA_10', 'SMA_30','SMA_100', 'SMA_200',
            'EMA_20',  'EMA_200', 'RSI_14', 'MACD', 'Signal_Line',
            'Upper_Band', 'Lower_Band', 'ATR_14', 'ADX_14', 'CCI_14', 'OBV', '%K', '%D', 'hour', 'day_of_week'] + [f'lag_{lag}' for lag in range(1,6)]

X = df[features]
y = df['target'] #価格が上昇すれば1下落すれば0

# %%
# データの分割（時間ベースでの分割）
split_date = '2024-01-01'
X_train = X[X.index < split_date]
X_test = X[X.index >= split_date]
y_train = y[y.index < split_date]
y_test = y[y.index >= split_date]

# %%
# XGBoostの分類モデルをインスタンス化
model = xgb.XGBClassifier(
    objective='binary:logistic',
    n_estimators=100,
    learning_rate=0.1,
    max_depth=5,
    random_state=42,
    use_label_encoder=False
)

# モデルの学習
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
# 予測
y_pred = model.predict(X_test)

# y_testと同じインデックスをy_predに設定
y_pred = pd.Series(y_pred, index=y_test.index)

# 精度と評価指標の表示
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8257436167412477
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82      3720
#            1       0.83      0.83      0.83      3878
#
#     accuracy                           0.83      7598
#    macro avg       0.83      0.83      0.83      7598
# weighted avg       0.83      0.83      0.83      7598

# %%
np.savetxt("xgb_pred.csv", y_pred, delimiter=",")

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# 初期設定
initial_capital = 1000
capital = initial_capital  # 初期資金をリセット
capital_history = []
positions = []
buy_signals = []
sell_signals = []

leverage = 2  # レバレッジ

# 現在のポジションの状態を示す変数
current_position = 0  # 1=ロング, -1=ショート, 0=ポジションなし

# テスト期間の日付リスト
test_dates = X_test.index

for i in range(len(test_dates) - 1):
    date = test_dates[i]
    prediction = y_pred[i]
    close_price = df.loc[date, 'close']
    next_date = test_dates[i + 1]
    next_close_price = df.loc[next_date, 'close']
    
    # ポジションの決定と変更
    if prediction == 1:  # 上がると予想
        if current_position == -1:  # 現在ショートなら決済してロングに変更
            sell_signals.append((date, close_price))  # ショート決済
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        elif current_position == 0:
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        else:
            current_position = 1
        

    elif prediction == 0:  # 下がると予想
        if current_position == 1:  # 現在ロングなら決済してショートに変更
            buy_signals.append((date, close_price))  # ロング決済
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        elif current_position == 0:
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        else:
            current_position = -1

    # リターンの計算
    ret = (next_close_price - close_price) / close_price * current_position * leverage
    capital = capital * (1 + ret)
    capital_history.append(capital)
    positions.append(current_position)

# バックテスト結果のデータフレーム作成
backtest_results = pd.DataFrame(index=test_dates[:-1])
backtest_results['Capital'] = capital_history
backtest_results['Position'] = positions

# リターンの計算
backtest_results['Return'] = backtest_results['Capital'].pct_change().fillna(0)

# シャープレシオの計算（リスクフリーレートは0と仮定）
sharpe_ratio = (backtest_results['Return'].mean() / backtest_results['Return'].std()) * np.sqrt(365 * 24)

print('Final capital:', capital)
print('Sharpe Ratio:', sharpe_ratio)

# 資産推移と売買のプロット
plt.figure(figsize=(12, 12))

# 1つ目のグラフ: 資産推移のプロット
plt.subplot(2, 1, 1)
plt.plot(backtest_results.index, backtest_results['Capital'], label='Capital Over Time')
plt.title('Capital Over Time')
plt.xlabel('Date')
plt.ylabel('Capital')
plt.legend()

# 2つ目のグラフ: BTC価格と売買シグナルのプロット
plt.subplot(2, 1, 2)
plt.plot(df.loc[test_dates[:-1], 'close'], label='BTC Price', color='blue')

# 買いのシグナル（緑の丸）
if buy_signals:
    buy_dates, buy_prices = zip(*buy_signals)
    plt.scatter(buy_dates, buy_prices, color='green', label='Buy Signal', marker='o')

# 売りのシグナル（赤の丸）
if sell_signals:
    sell_dates, sell_prices = zip(*sell_signals)
    plt.scatter(sell_dates, sell_prices, color='red', label='Sell Signal', marker='o')

plt.title('BTC Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('BTC Price')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final capital: 148.34229716856106
# Sharpe Ratio: -1.594210334297292

# %% [markdown]
# # ハイパーパラメータチューニング

# %%
param_grid = {
    'max_depth': [3, 5, 7],           # ツリーの深さ（深くしすぎると過学習のリスク）
    'learning_rate': [0.01, 0.1, 0.2],# 学習率（小さくすると学習は遅いが精度が安定しやすい）
    'n_estimators': [50, 100, 200],    # ツリーの数（多いほどモデルが複雑に）
    'subsample': [0.7, 0.8, 1.0],     # 各ツリーのサンプル使用割合
    'colsample_bytree': [0.7, 0.8, 1.0] # 各ツリーの特徴量使用割合
}

grid_search = GridSearchCV(
    estimator=xgb.XGBClassifier(objective='binary:logistic'),
    param_grid=param_grid,
    scoring='accuracy',
    cv=3,
    n_jobs=-1
)

# グリッドサーチで最適なパラメータを探索
grid_search.fit(X_train, y_train)

# 最適なパラメータでモデルを再作成
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8}

# %%
model = xgb.XGBClassifier(**best_params)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# 予測
y_pred = model.predict(X_test)

# y_testと同じインデックスをy_predに設定
y_pred = pd.Series(y_pred, index=y_test.index)

# 精度と評価指標の表示
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.826533298236378
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82      3720
#            1       0.83      0.84      0.83      3878
#
#     accuracy                           0.83      7598
#    macro avg       0.83      0.83      0.83      7598
# weighted avg       0.83      0.83      0.83      7598

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
eval_set = [(X_train, y_train), (X_test, y_test)]
model = xgb.XGBClassifier(**best_params, early_stopping_rounds=10)
model.fit(X_train, y_train,  eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-logloss:0.67861	validation_1-logloss:0.67799
# [1]	validation_0-logloss:0.65505	validation_1-logloss:0.65349
# [2]	validation_0-logloss:0.64316	validation_1-logloss:0.64204
# [3]	validation_0-logloss:0.62261	validation_1-logloss:0.62028
# [4]	validation_0-logloss:0.60610	validation_1-logloss:0.60358
# [5]	validation_0-logloss:0.58662	validation_1-logloss:0.58444
# [6]	validation_0-logloss:0.56910	validation_1-logloss:0.56759
# [7]	validation_0-logloss:0.55736	validation_1-logloss:0.55591
# [8]	validation_0-logloss:0.55047	validation_1-logloss:0.55043
# [9]	validation_0-logloss:0.54720	validation_1-logloss:0.54769
# [10]	validation_0-logloss:0.53428	validation_1-logloss:0.53524
# [11]	validation_0-logloss:0.52922	validation_1-logloss:0.53090
# [12]	validation_0-logloss:0.52021	validation_1-logloss:0.52185
# [13]	validation_0-logloss:0.51075	validation_1-logloss:0.51278
# [14]	validation_0-logloss:0.50606	validation_1-logloss:0.50925
# [15]	validation_0-logloss:0.49822	validation_1-logloss:0.50128
# [16]	validation_0-logloss:0.48979	validation_1-logloss:0.49344
# [17]	validation_0-logloss:0.48597	validation_1-logloss:0.49024
# [18]	validation_0-logloss:0.48250	validation_1-logloss:0.48734
# [19]	validation_0-logloss:0.48047	validation_1-logloss:0.48593
# [20]	validation_0-logloss:0.47454	validation_1-logloss:0.48043
# [21]	validation_0-logloss:0.47388	validation_1-logloss:0.47940
# [22]	validation_0-logloss:0.46830	validation_1-logloss:0.47379
# [23]	validation_0-logloss:0.46399	validation_1-logloss:0.46919
# [24]	validation_0-logloss:0.45914	validation_1-logloss:0.46504
# [25]	validation_0-logloss:0.45661	validation_1-logloss:0.46298
# [26]	validation_0-logloss:0.45278	validation_1-logloss:0.45928
# [27]	validation_0-logloss:0.45179	validation_1-logloss:0.45854
# [28]	validation_0-logloss:0.44746	validation_1-logloss:0.45465
# [29]	validation_0-logloss:0.44386	validation_1-logloss:0.45124
# [30]	validation_0-logloss:0.44069	validation_1-logloss:0.44820
# [31]	validation_0-logloss:0.43919	validation_1-logloss:0.44661
# [32]	validation_0-logloss:0.43712	validation_1-logloss:0.44491
# [33]	validation_0-logloss:0.43668	validation_1-logloss:0.44502
# [34]	validation_0-logloss:0.43349	validation_1-logloss:0.44206
# [35]	validation_0-logloss:0.43171	validation_1-logloss:0.44074
# [36]	validation_0-logloss:0.42998	validation_1-logloss:0.43921
# [37]	validation_0-logloss:0.42880	validation_1-logloss:0.43826
# [38]	validation_0-logloss:0.42791	validation_1-logloss:0.43729
# [39]	validation_0-logloss:0.42622	validation_1-logloss:0.43572
# [40]	validation_0-logloss:0.42550	validation_1-logloss:0.43540
# [41]	validation_0-logloss:0.42141	validation_1-logloss:0.43179
# [42]	validation_0-logloss:0.41732	validation_1-logloss:0.42835
# [43]	validation_0-logloss:0.41669	validation_1-logloss:0.42801
# [44]	validation_0-logloss:0.41417	validation_1-logloss:0.42555
# [45]	validation_0-logloss:0.41387	validation_1-logloss:0.42533
# [46]	validation_0-logloss:0.41158	validation_1-logloss:0.42324
# [47]	validation_0-logloss:0.40985	validation_1-logloss:0.42217
# [48]	validation_0-logloss:0.40850	validation_1-logloss:0.42119
# [49]	validation_0-logloss:0.40652	validation_1-logloss:0.41905
# [50]	validation_0-logloss:0.40425	validation_1-logloss:0.41696
# [51]	validation_0-logloss:0.40283	validation_1-logloss:0.41605
# [52]	validation_0-logloss:0.40101	validation_1-logloss:0.41448
# [53]	validation_0-logloss:0.40001	validation_1-logloss:0.41370
# [54]	validation_0-logloss:0.39793	validation_1-logloss:0.41213
# [55]	validation_0-logloss:0.39740	validation_1-logloss:0.41204
# [56]	validation_0-logloss:0.39497	validation_1-logloss:0.40994
# [57]	validation_0-logloss:0.39379	validation_1-logloss:0.40918
# [58]	validation_0-logloss:0.39275	validation_1-logloss:0.40842
# [59]	validation_0-logloss:0.39156	validation_1-logloss:0.40744
# [60]	validation_0-logloss:0.39087	validation_1-logloss:0.40694
# [61]	validation_0-logloss:0.38985	validation_1-logloss:0.40640
# [62]	validation_0-logloss:0.38860	validation_1-logloss:0.40523
# [63]	validation_0-logloss:0.38744	validation_1-logloss:0.40421
# [64]	validation_0-logloss:0.38617	validation_1-logloss:0.40320
# [65]	validation_0-logloss:0.38561	validation_1-logloss:0.40271
# [66]	validation_0-logloss:0.38418	validation_1-logloss:0.40178
# [67]	validation_0-logloss:0.38393	validation_1-logloss:0.40183
# [68]	validation_0-logloss:0.38311	validation_1-logloss:0.40128
# [69]	validation_0-logloss:0.38282	validation_1-logloss:0.40111
# [70]	validation_0-logloss:0.38187	validation_1-logloss:0.40035
# [71]	validation_0-logloss:0.38152	validation_1-logloss:0.39994
# [72]	validation_0-logloss:0.38046	validation_1-logloss:0.39914
# [73]	validation_0-logloss:0.37939	validation_1-logloss:0.39828
# [74]	validation_0-logloss:0.37864	validation_1-logloss:0.39774
# [75]	validation_0-logloss:0.37754	validation_1-logloss:0.39693
# [76]	validation_0-logloss:0.37628	validation_1-logloss:0.39615
# [77]	validation_0-logloss:0.37590	validation_1-logloss:0.39610
# [78]	validation_0-logloss:0.37451	validation_1-logloss:0.39531
# [79]	validation_0-logloss:0.37365	validation_1-logloss:0.39490
# [80]	validation_0-logloss:0.37319	validation_1-logloss:0.39454
# [81]	validation_0-logloss:0.37252	validation_1-logloss:0.39409
# [82]	validation_0-logloss:0.37131	validation_1-logloss:0.39326
# [83]	validation_0-logloss:0.37084	validation_1-logloss:0.39294
# [84]	validation_0-logloss:0.37029	validation_1-logloss:0.39259
# [85]	validation_0-logloss:0.36955	validation_1-logloss:0.39202
# [86]	validation_0-logloss:0.36883	validation_1-logloss:0.39142
# [87]	validation_0-logloss:0.36837	validation_1-logloss:0.39114
# [88]	validation_0-logloss:0.36764	validation_1-logloss:0.39067
# [89]	validation_0-logloss:0.36665	validation_1-logloss:0.39005
# [90]	validation_0-logloss:0.36635	validation_1-logloss:0.38994
# [91]	validation_0-logloss:0.36602	validation_1-logloss:0.38969
# [92]	validation_0-logloss:0.36566	validation_1-logloss:0.38948
# [93]	validation_0-logloss:0.36507	validation_1-logloss:0.38927
# [94]	validation_0-logloss:0.36425	validation_1-logloss:0.38866
# [95]	validation_0-logloss:0.36392	validation_1-logloss:0.38866
# [96]	validation_0-logloss:0.36321	validation_1-logloss:0.38805
# [97]	validation_0-logloss:0.36272	validation_1-logloss:0.38776
# [98]	validation_0-logloss:0.36217	validation_1-logloss:0.38793
# [99]	validation_0-logloss:0.36137	validation_1-logloss:0.38741
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# 予測
y_pred = model.predict(X_test)

# y_testと同じインデックスをy_predに設定
y_pred = pd.Series(y_pred, index=y_test.index)

# 精度と評価指標の表示
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Accuracy: 0.826533298236378
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82      3720
#            1       0.83      0.84      0.83      3878
#
#     accuracy                           0.83      7598
#    macro avg       0.83      0.83      0.83      7598
# weighted avg       0.83      0.83      0.83      7598

# %%
# 初期設定
initial_capital = 1000
capital = initial_capital  # 初期資金をリセット
capital_history = []
positions = []
buy_signals = []
sell_signals = []

leverage = 2  # レバレッジ

# 現在のポジションの状態を示す変数
current_position = 0  # 1=ロング, -1=ショート, 0=ポジションなし

# テスト期間の日付リスト
test_dates = X_test.index

for i in range(len(test_dates) - 1):
    date = test_dates[i]
    prediction = y_pred[i]
    close_price = df.loc[date, 'close']
    next_date = test_dates[i + 1]
    next_close_price = df.loc[next_date, 'close']
    
    # ポジションの決定と変更
    if prediction == 1:  # 上がると予想
        if current_position == -1:  # 現在ショートなら決済してロングに変更
            sell_signals.append((date, close_price))  # ショート決済
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        elif current_position == 0:
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        else:
            current_position = 1
        

    elif prediction == 0:  # 下がると予想
        if current_position == 1:  # 現在ロングなら決済してショートに変更
            buy_signals.append((date, close_price))  # ロング決済
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        elif current_position == 0:
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        else:
            current_position = -1

    # リターンの計算
    ret = (next_close_price - close_price) / close_price * current_position * leverage
    capital = capital * (1 + ret)
    capital_history.append(capital)
    positions.append(current_position)

# バックテスト結果のデータフレーム作成
backtest_results = pd.DataFrame(index=test_dates[:-1])
backtest_results['Capital'] = capital_history
backtest_results['Position'] = positions

# リターンの計算
backtest_results['Return'] = backtest_results['Capital'].pct_change().fillna(0)

# シャープレシオの計算（リスクフリーレートは0と仮定）
sharpe_ratio = (backtest_results['Return'].mean() / backtest_results['Return'].std()) * np.sqrt(365 * 24)

print('Final capital:', capital)
print('Sharpe Ratio:', sharpe_ratio)

# 資産推移と売買のプロット
plt.figure(figsize=(12, 12))

# 1つ目のグラフ: 資産推移のプロット
plt.subplot(2, 1, 1)
plt.plot(backtest_results.index, backtest_results['Capital'], label='Capital Over Time')
plt.title('Capital Over Time')
plt.xlabel('Date')
plt.ylabel('Capital')
plt.legend()

# 2つ目のグラフ: BTC価格と売買シグナルのプロット
plt.subplot(2, 1, 2)
plt.plot(df.loc[test_dates[:-1], 'close'], label='BTC Price', color='blue')

# 買いのシグナル（緑の丸）
if buy_signals:
    buy_dates, buy_prices = zip(*buy_signals)
    plt.scatter(buy_dates, buy_prices, color='green', label='Buy Signal', marker='o')

# 売りのシグナル（赤の丸）
if sell_signals:
    sell_dates, sell_prices = zip(*sell_signals)
    plt.scatter(sell_dates, sell_prices, color='red', label='Sell Signal', marker='o')

plt.title('BTC Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('BTC Price')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final capital: 144.47043085303557
# Sharpe Ratio: -1.6232875726926261

# %%
# 予測結果をCSVファイルに保存
np.savetxt("xgb_tuned_pred.csv", y_pred, delimiter=",")
