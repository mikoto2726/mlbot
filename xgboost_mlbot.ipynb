# %%
# 必要なライブラリのインポート
import numpy as np
import pandas as pd
import xgboost as xgb
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
import ccxt
from datetime import datetime, timedelta
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
import warnings
import os
import sweetviz as sv
from IPython.display import IFrame
import time
import requests
from sklearn.model_selection import cross_val_score
warnings.filterwarnings('ignore')

# %%
# Binanceのインスタンスを作成（レートリミットを有効化）
exchange = ccxt.binance({
    'enableRateLimit': True,
})

# BTC/USDTのデータを取得
symbol = 'BTC/USDT'
timeframe = '1h'  # 15分足のデータ
since = exchange.parse8601('2020-01-01T00:00:00Z')  # データの開始日

# データを取得する関数（例外処理と進行状況の追加）
def fetch_all_ohlcv(symbol, timeframe, since):
    all_ohlcv = []
    now = exchange.milliseconds()
    while since < now:
        try:
            ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since, limit=1000)
            if not ohlcv:
                break
            since = ohlcv[-1][0] + 1  # タイムスタンプを更新
            all_ohlcv.extend(ohlcv)
        except Exception as e:
            print(f'An error occurred: {e}')
            # リトライのために一時停止
            time.sleep(5)
            continue
    return all_ohlcv

# データを取得
ohlcv = fetch_all_ohlcv(symbol, timeframe, since)
data = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])

# タイムスタンプを変換
data['timestamp'] = pd.to_datetime(data['timestamp'], unit='ms')

# CSVファイルとして保存
data.to_csv('btc_usdt_1h_2018_to_now.csv', index=False)

print('Data fetching and saving completed.')
# Out:
# Data fetching and saving completed.

# %%
# データの読み込みと文字列として保存されている日時情報を日時型のデータに変換
df = pd.read_csv('btc_usdt_1h_2018_to_now.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
# タイムスタンプでソートとインデックスのリセット
df.sort_values('timestamp', inplace=True)#inplaceで新しいdataframeを作成せず元のを変更
# 列をインデックス（行ラベル）として設定
df.set_index('timestamp', inplace=True)

# %%
df['close'].plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
# 特徴量エンジニアリング
# 移動平均線の計算
df['SMA_10'] = df['close'].rolling(window=10).mean()
df['SMA_20'] = df['close'].rolling(window=20).mean()
df['SMA_30'] = df['close'].rolling(window=30).mean()
df['SMA_100'] = df['close'].rolling(window=100).mean()
df['SMA_200'] = df['close'].rolling(window=200).mean()

# 指数移動平均線の計算
df['EMA_20'] = df['close'].ewm(span=20, adjust=False).mean()
df['EMA_200'] = df['close'].ewm(span=200, adjust=False).mean()

# RSIの計算
def compute_RSI(data, time_window):
    diff = data.diff(1) #1つ前の行との違い
    up_chg = diff.clip(lower=0) #差分が負の物は0に変換
    down_chg = -diff.clip(upper=0) #差分が0より大きいものを全て0に置き換える
    up_chg_avg = up_chg.ewm(com=time_window - 1, min_periods=time_window).mean() #価格が上昇した指数移動平均
    down_chg_avg = down_chg.ewm(com=time_window - 1, min_periods=time_window).mean()
    rs = up_chg_avg / down_chg_avg #上昇した強さと下落した強さの比率
    rsi = 100 - 100 / (1 + rs) 
    return rsi

df['RSI_14'] = compute_RSI(df['close'], 14)

# MACDの計算
df['EMA_12'] = df['close'].ewm(span=12, adjust=False).mean()
df['EMA_26'] = df['close'].ewm(span=26, adjust=False).mean()
df['MACD'] = df['EMA_12'] - df['EMA_26']
df['Signal_Line'] = df['MACD'].ewm(span=9, adjust=False).mean()

# ボリンジャーバンドの計算
df['STD_20'] = df['close'].rolling(window=20).std() #stdは標準偏差(データのばらつき度合い)を計算
df['Upper_Band'] = df['SMA_20'] + (df['STD_20'] * 2)
df['Lower_Band'] = df['SMA_20'] - (df['STD_20'] * 2)

# 遅延特徴量の作成
for lag in range(1, 6): #shift(lag) は、df['close'] のデータを lag 分だけ下にシフト
    df[f'lag_{lag}'] = df['close'].shift(lag) #lag_1からlag_5 までの5つの遅延列が作成

# 時間に関する特徴量
df['hour'] = df.index.hour
df['day_of_week'] = df.index.dayofweek #曜日は0から6の値で表される

#ATR（平均真の範囲、Average True Range）
df['TR'] = df['high'] - df['low']
df['ATR_14'] = df['TR'].rolling(window=14).mean()

#ADX（平均方向性指数、Average Directional Index）
def compute_ADX(data, period=14):
    high = data['high']
    low = data['low']
    close = data['close']
    
    plus_dm = high.diff()
    minus_dm = low.diff()

    plus_dm[plus_dm < 0] = 0
    minus_dm[minus_dm > 0] = 0

    tr = high.combine(low, max) - low.combine(close.shift(), min)

    atr = tr.rolling(window=period).mean()

    plus_di = 100 * (plus_dm.ewm(alpha=1/period).mean() / atr)
    minus_di = abs(100 * (minus_dm.ewm(alpha=1/period).mean() / atr))
    dx = (abs(plus_di - minus_di) / (plus_di + minus_di)) * 100
    adx = dx.rolling(window=period).mean()
    
    return adx

df['ADX_14'] = compute_ADX(df)

#CCI（商品チャンネル指数、Commodity Channel Index）
df['TP'] = (df['high'] + df['low'] + df['close']) / 3
df['CCI_14'] = (df['TP'] - df['TP'].rolling(window=14).mean()) / (0.015 * df['TP'].rolling(window=14).std())

#OBV（オンバランスボリューム、On-Balance Volume）
df['OBV'] = (np.sign(df['close'].diff()) * df['volume']).fillna(0).cumsum()

#Stochastic Oscillator（ストキャスティクス）
df['L14'] = df['low'].rolling(window=14).min()
df['H14'] = df['high'].rolling(window=14).max()
df['%K'] = 100 * (df['close'] - df['L14']) / (df['H14'] - df['L14'])
df['%D'] = df['%K'].rolling(window=3).mean()

# %%
# 目標変数の作成
df['return'] = df['close'].pct_change().shift(-1) #前の行とのパーセンテージの変化
df['target'] = (df['return'] > 0).astype(int) #価格が上昇したらTrue

# %%
# 欠損値の削除
df.dropna(inplace=True)

# %%
# 特徴量と目標変数の定義
features = ['open', 'high', 'low', 'close', 'volume', 'SMA_10', 'SMA_30','SMA_100', 'SMA_200',
            'EMA_20',  'EMA_200', 'RSI_14', 'MACD', 'Signal_Line',
            'Upper_Band', 'Lower_Band', 'ATR_14', 'ADX_14', 'CCI_14', 'OBV', '%K', '%D', 'hour', 'day_of_week'] + [f'lag_{lag}' for lag in range(1,6)]

X = df[features]
y = df['target'] #価格が上昇すれば1下落すれば0

# %%
# データの分割（時間ベースでの分割）
split_date = '2024-01-01'
X_train = X[X.index < split_date]
X_test = X[X.index >= split_date]
y_train = y[y.index < split_date]
y_test = y[y.index >= split_date]

# %%
# XGBoostの分類モデルをインスタンス化
model = xgb.XGBClassifier(
    objective='binary:logistic',
    n_estimators=100,
    learning_rate=0.1,
    max_depth=5,
    random_state=42,
    use_label_encoder=False
)

# モデルの学習
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
# 予測
y_pred = model.predict(X_test)

# y_testと同じインデックスをy_predに設定
y_pred = pd.Series(y_pred, index=y_test.index)

# 精度と評価指標の表示
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5214462469067913
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.58      0.54      3574
#            1       0.53      0.47      0.50      3700
#
#     accuracy                           0.52      7274
#    macro avg       0.52      0.52      0.52      7274
# weighted avg       0.52      0.52      0.52      7274

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# 初期設定
initial_capital = 1000
capital = initial_capital  # 初期資金をリセット
capital_history = []
positions = []
buy_signals = []
sell_signals = []

leverage = 2  # レバレッジ

# 現在のポジションの状態を示す変数
current_position = 0  # 1=ロング, -1=ショート, 0=ポジションなし

# テスト期間の日付リスト
test_dates = X_test.index

for i in range(len(test_dates) - 1):
    date = test_dates[i]
    prediction = y_pred[i]
    close_price = df.loc[date, 'close']
    next_date = test_dates[i + 1]
    next_close_price = df.loc[next_date, 'close']
    
    # ポジションの決定と変更
    if prediction == 1:  # 上がると予想
        if current_position == -1:  # 現在ショートなら決済してロングに変更
            sell_signals.append((date, close_price))  # ショート決済
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        elif current_position == 0:
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        else:
            current_position = 1
        

    elif prediction == 0:  # 下がると予想
        if current_position == 1:  # 現在ロングなら決済してショートに変更
            buy_signals.append((date, close_price))  # ロング決済
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        elif current_position == 0:
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        else:
            current_position = -1

    # リターンの計算
    ret = (next_close_price - close_price) / close_price * current_position * leverage
    capital = capital * (1 + ret)
    capital_history.append(capital)
    positions.append(current_position)

# バックテスト結果のデータフレーム作成
backtest_results = pd.DataFrame(index=test_dates[:-1])
backtest_results['Capital'] = capital_history
backtest_results['Position'] = positions

# リターンの計算
backtest_results['Return'] = backtest_results['Capital'].pct_change().fillna(0)

# シャープレシオの計算（リスクフリーレートは0と仮定）
sharpe_ratio = (backtest_results['Return'].mean() / backtest_results['Return'].std()) * np.sqrt(365 * 24)

print('Final capital:', capital)
print('Sharpe Ratio:', sharpe_ratio)

# 資産推移と売買のプロット
plt.figure(figsize=(12, 12))

# 1つ目のグラフ: 資産推移のプロット
plt.subplot(2, 1, 1)
plt.plot(backtest_results.index, backtest_results['Capital'], label='Capital Over Time')
plt.title('Capital Over Time')
plt.xlabel('Date')
plt.ylabel('Capital')
plt.legend()

# 2つ目のグラフ: BTC価格と売買シグナルのプロット
plt.subplot(2, 1, 2)
plt.plot(df.loc[test_dates[:-1], 'close'], label='BTC Price', color='blue')

# 買いのシグナル（緑の丸）
if buy_signals:
    buy_dates, buy_prices = zip(*buy_signals)
    plt.scatter(buy_dates, buy_prices, color='green', label='Buy Signal', marker='o')

# 売りのシグナル（赤の丸）
if sell_signals:
    sell_dates, sell_prices = zip(*sell_signals)
    plt.scatter(sell_dates, sell_prices, color='red', label='Sell Signal', marker='o')

plt.title('BTC Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('BTC Price')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final capital: 952.81071079621
# Sharpe Ratio: 0.4750056374331798

# %% [markdown]
# # ハイパーパラメータチューニング

# %%
param_grid = {
    'max_depth': [3, 5, 7],           # ツリーの深さ（深くしすぎると過学習のリスク）
    'learning_rate': [0.01, 0.1, 0.2],# 学習率（小さくすると学習は遅いが精度が安定しやすい）
    'n_estimators': [50, 100, 200],    # ツリーの数（多いほどモデルが複雑に）
    'subsample': [0.7, 0.8, 1.0],     # 各ツリーのサンプル使用割合
    'colsample_bytree': [0.7, 0.8, 1.0] # 各ツリーの特徴量使用割合
}

grid_search = GridSearchCV(
    estimator=xgb.XGBClassifier(objective='binary:logistic'),
    param_grid=param_grid,
    scoring='accuracy',
    cv=3,
    n_jobs=-1
)

# グリッドサーチで最適なパラメータを探索
grid_search.fit(X_train, y_train)

# 最適なパラメータでモデルを再作成
best_params = grid_search.best_params_
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.7}

# %%
model = xgb.XGBClassifier(**best_params)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# 予測
y_pred = model.predict(X_test)

# y_testと同じインデックスをy_predに設定
y_pred = pd.Series(y_pred, index=y_test.index)

# 精度と評価指標の表示
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5309320868847952
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.50      0.51      3574
#            1       0.54      0.56      0.55      3700
#
#     accuracy                           0.53      7274
#    macro avg       0.53      0.53      0.53      7274
# weighted avg       0.53      0.53      0.53      7274

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
eval_set = [(X_train, y_train), (X_test, y_test)]
model = xgb.XGBClassifier(**best_params, early_stopping_rounds=10)
model.fit(X_train, y_train,  eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-logloss:0.69291	validation_1-logloss:0.69292
# [1]	validation_0-logloss:0.69281	validation_1-logloss:0.69287
# [2]	validation_0-logloss:0.69270	validation_1-logloss:0.69278
# [3]	validation_0-logloss:0.69260	validation_1-logloss:0.69271
# [4]	validation_0-logloss:0.69251	validation_1-logloss:0.69264
# [5]	validation_0-logloss:0.69242	validation_1-logloss:0.69257
# [6]	validation_0-logloss:0.69234	validation_1-logloss:0.69251
# [7]	validation_0-logloss:0.69225	validation_1-logloss:0.69245
# [8]	validation_0-logloss:0.69217	validation_1-logloss:0.69243
# [9]	validation_0-logloss:0.69208	validation_1-logloss:0.69238
# [10]	validation_0-logloss:0.69201	validation_1-logloss:0.69229
# [11]	validation_0-logloss:0.69192	validation_1-logloss:0.69222
# [12]	validation_0-logloss:0.69183	validation_1-logloss:0.69216
# [13]	validation_0-logloss:0.69175	validation_1-logloss:0.69209
# [14]	validation_0-logloss:0.69167	validation_1-logloss:0.69204
# [15]	validation_0-logloss:0.69159	validation_1-logloss:0.69199
# [16]	validation_0-logloss:0.69151	validation_1-logloss:0.69193
# [17]	validation_0-logloss:0.69144	validation_1-logloss:0.69190
# [18]	validation_0-logloss:0.69136	validation_1-logloss:0.69184
# [19]	validation_0-logloss:0.69129	validation_1-logloss:0.69179
# [20]	validation_0-logloss:0.69121	validation_1-logloss:0.69173
# [21]	validation_0-logloss:0.69113	validation_1-logloss:0.69168
# [22]	validation_0-logloss:0.69106	validation_1-logloss:0.69162
# [23]	validation_0-logloss:0.69099	validation_1-logloss:0.69161
# [24]	validation_0-logloss:0.69092	validation_1-logloss:0.69159
# [25]	validation_0-logloss:0.69086	validation_1-logloss:0.69156
# [26]	validation_0-logloss:0.69079	validation_1-logloss:0.69154
# [27]	validation_0-logloss:0.69072	validation_1-logloss:0.69150
# [28]	validation_0-logloss:0.69066	validation_1-logloss:0.69144
# [29]	validation_0-logloss:0.69059	validation_1-logloss:0.69140
# [30]	validation_0-logloss:0.69053	validation_1-logloss:0.69138
# [31]	validation_0-logloss:0.69046	validation_1-logloss:0.69134
# [32]	validation_0-logloss:0.69040	validation_1-logloss:0.69128
# [33]	validation_0-logloss:0.69034	validation_1-logloss:0.69124
# [34]	validation_0-logloss:0.69028	validation_1-logloss:0.69119
# [35]	validation_0-logloss:0.69021	validation_1-logloss:0.69115
# [36]	validation_0-logloss:0.69015	validation_1-logloss:0.69113
# [37]	validation_0-logloss:0.69010	validation_1-logloss:0.69109
# [38]	validation_0-logloss:0.69004	validation_1-logloss:0.69106
# [39]	validation_0-logloss:0.68998	validation_1-logloss:0.69102
# [40]	validation_0-logloss:0.68993	validation_1-logloss:0.69099
# [41]	validation_0-logloss:0.68987	validation_1-logloss:0.69095
# [42]	validation_0-logloss:0.68982	validation_1-logloss:0.69091
# [43]	validation_0-logloss:0.68977	validation_1-logloss:0.69087
# [44]	validation_0-logloss:0.68971	validation_1-logloss:0.69084
# [45]	validation_0-logloss:0.68966	validation_1-logloss:0.69081
# [46]	validation_0-logloss:0.68961	validation_1-logloss:0.69079
# [47]	validation_0-logloss:0.68956	validation_1-logloss:0.69076
# [48]	validation_0-logloss:0.68951	validation_1-logloss:0.69072
# [49]	validation_0-logloss:0.68946	validation_1-logloss:0.69068
# [50]	validation_0-logloss:0.68942	validation_1-logloss:0.69066
# [51]	validation_0-logloss:0.68936	validation_1-logloss:0.69063
# [52]	validation_0-logloss:0.68932	validation_1-logloss:0.69059
# [53]	validation_0-logloss:0.68927	validation_1-logloss:0.69057
# [54]	validation_0-logloss:0.68922	validation_1-logloss:0.69053
# [55]	validation_0-logloss:0.68918	validation_1-logloss:0.69053
# [56]	validation_0-logloss:0.68913	validation_1-logloss:0.69051
# [57]	validation_0-logloss:0.68909	validation_1-logloss:0.69049
# [58]	validation_0-logloss:0.68904	validation_1-logloss:0.69047
# [59]	validation_0-logloss:0.68900	validation_1-logloss:0.69044
# [60]	validation_0-logloss:0.68896	validation_1-logloss:0.69042
# [61]	validation_0-logloss:0.68892	validation_1-logloss:0.69040
# [62]	validation_0-logloss:0.68888	validation_1-logloss:0.69039
# [63]	validation_0-logloss:0.68884	validation_1-logloss:0.69037
# [64]	validation_0-logloss:0.68880	validation_1-logloss:0.69035
# [65]	validation_0-logloss:0.68876	validation_1-logloss:0.69034
# [66]	validation_0-logloss:0.68872	validation_1-logloss:0.69033
# [67]	validation_0-logloss:0.68868	validation_1-logloss:0.69032
# [68]	validation_0-logloss:0.68865	validation_1-logloss:0.69030
# [69]	validation_0-logloss:0.68860	validation_1-logloss:0.69028
# [70]	validation_0-logloss:0.68856	validation_1-logloss:0.69027
# [71]	validation_0-logloss:0.68852	validation_1-logloss:0.69025
# [72]	validation_0-logloss:0.68848	validation_1-logloss:0.69023
# [73]	validation_0-logloss:0.68845	validation_1-logloss:0.69022
# [74]	validation_0-logloss:0.68841	validation_1-logloss:0.69023
# [75]	validation_0-logloss:0.68837	validation_1-logloss:0.69021
# [76]	validation_0-logloss:0.68833	validation_1-logloss:0.69021
# [77]	validation_0-logloss:0.68830	validation_1-logloss:0.69019
# [78]	validation_0-logloss:0.68826	validation_1-logloss:0.69017
# [79]	validation_0-logloss:0.68822	validation_1-logloss:0.69015
# [80]	validation_0-logloss:0.68819	validation_1-logloss:0.69014
# [81]	validation_0-logloss:0.68815	validation_1-logloss:0.69012
# [82]	validation_0-logloss:0.68811	validation_1-logloss:0.69009
# [83]	validation_0-logloss:0.68808	validation_1-logloss:0.69008
# [84]	validation_0-logloss:0.68805	validation_1-logloss:0.69009
# [85]	validation_0-logloss:0.68801	validation_1-logloss:0.69008
# [86]	validation_0-logloss:0.68798	validation_1-logloss:0.69008
# [87]	validation_0-logloss:0.68795	validation_1-logloss:0.69007
# [88]	validation_0-logloss:0.68792	validation_1-logloss:0.69005
# [89]	validation_0-logloss:0.68788	validation_1-logloss:0.69008
# [90]	validation_0-logloss:0.68785	validation_1-logloss:0.69009
# [91]	validation_0-logloss:0.68782	validation_1-logloss:0.69011
# [92]	validation_0-logloss:0.68779	validation_1-logloss:0.69010
# [93]	validation_0-logloss:0.68776	validation_1-logloss:0.69011
# [94]	validation_0-logloss:0.68773	validation_1-logloss:0.69010
# [95]	validation_0-logloss:0.68770	validation_1-logloss:0.69009
# [96]	validation_0-logloss:0.68766	validation_1-logloss:0.69008
# [97]	validation_0-logloss:0.68763	validation_1-logloss:0.69005
# [98]	validation_0-logloss:0.68759	validation_1-logloss:0.69002
# [99]	validation_0-logloss:0.68756	validation_1-logloss:0.69001
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# 予測
y_pred = model.predict(X_test)

# y_testと同じインデックスをy_predに設定
y_pred = pd.Series(y_pred, index=y_test.index)

# 精度と評価指標の表示
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Accuracy: 0.5309320868847952
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.50      0.51      3574
#            1       0.54      0.56      0.55      3700
#
#     accuracy                           0.53      7274
#    macro avg       0.53      0.53      0.53      7274
# weighted avg       0.53      0.53      0.53      7274

# %%
# 初期設定
initial_capital = 1000
capital = initial_capital  # 初期資金をリセット
capital_history = []
positions = []
buy_signals = []
sell_signals = []

leverage = 2  # レバレッジ

# 現在のポジションの状態を示す変数
current_position = 0  # 1=ロング, -1=ショート, 0=ポジションなし

# テスト期間の日付リスト
test_dates = X_test.index

for i in range(len(test_dates) - 1):
    date = test_dates[i]
    prediction = y_pred[i]
    close_price = df.loc[date, 'close']
    next_date = test_dates[i + 1]
    next_close_price = df.loc[next_date, 'close']
    
    # ポジションの決定と変更
    if prediction == 1:  # 上がると予想
        if current_position == -1:  # 現在ショートなら決済してロングに変更
            sell_signals.append((date, close_price))  # ショート決済
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        elif current_position == 0:
            current_position = 1
            buy_signals.append((next_date, next_close_price))  # ロングエントリー

        else:
            current_position = 1
        

    elif prediction == 0:  # 下がると予想
        if current_position == 1:  # 現在ロングなら決済してショートに変更
            buy_signals.append((date, close_price))  # ロング決済
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        elif current_position == 0:
            current_position = -1
            sell_signals.append((next_date, next_close_price))  # ショートエントリー

        else:
            current_position = -1

    # リターンの計算
    ret = (next_close_price - close_price) / close_price * current_position * leverage
    capital = capital * (1 + ret)
    capital_history.append(capital)
    positions.append(current_position)

# バックテスト結果のデータフレーム作成
backtest_results = pd.DataFrame(index=test_dates[:-1])
backtest_results['Capital'] = capital_history
backtest_results['Position'] = positions

# リターンの計算
backtest_results['Return'] = backtest_results['Capital'].pct_change().fillna(0)

# シャープレシオの計算（リスクフリーレートは0と仮定）
sharpe_ratio = (backtest_results['Return'].mean() / backtest_results['Return'].std()) * np.sqrt(365 * 24)

print('Final capital:', capital)
print('Sharpe Ratio:', sharpe_ratio)

# 資産推移と売買のプロット
plt.figure(figsize=(12, 12))

# 1つ目のグラフ: 資産推移のプロット
plt.subplot(2, 1, 1)
plt.plot(backtest_results.index, backtest_results['Capital'], label='Capital Over Time')
plt.title('Capital Over Time')
plt.xlabel('Date')
plt.ylabel('Capital')
plt.legend()

# 2つ目のグラフ: BTC価格と売買シグナルのプロット
plt.subplot(2, 1, 2)
plt.plot(df.loc[test_dates[:-1], 'close'], label='BTC Price', color='blue')

# 買いのシグナル（緑の丸）
if buy_signals:
    buy_dates, buy_prices = zip(*buy_signals)
    plt.scatter(buy_dates, buy_prices, color='green', label='Buy Signal', marker='o')

# 売りのシグナル（赤の丸）
if sell_signals:
    sell_dates, sell_prices = zip(*sell_signals)
    plt.scatter(sell_dates, sell_prices, color='red', label='Sell Signal', marker='o')

plt.title('BTC Price with Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('BTC Price')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final capital: 952.81071079621
# Sharpe Ratio: 0.4750056374331798
